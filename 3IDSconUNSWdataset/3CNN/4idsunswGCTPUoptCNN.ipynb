# %% [markdown]
# ### **Data preprocessing**

# %%
# Google Drive
from google.colab import drive
drive.mount('/content/drive')

import numpy as np
import pandas as pd
from sklearn import metrics
from scipy.stats import zscore
import os
from tensorflow.keras.utils import get_file
from sklearn.preprocessing import normalize # , LabelEncoder

# Read the info about features
try:
    path = get_file('NUSW-NB15_features.csv', origin='https://www.unsw.adfa.edu.au/unsw-canberra-cyber/cybersecurity/ADFA-NB15-Datasets/NUSW-NB15_features.csv')
except:
    print('Error downloading')
    raise

# Read the info about features
print('Reading feature info...')
data_info = pd.read_csv(path, encoding = "ISO-8859-1", header=None).values
features = data_info[1:-2,:]
feature_names = features[:, 1]  # Names of the features in a list
feature_types = np.array([item.lower() for item in features[:, 2]])  # The types of the corresponding features in 'features_names'
                         
# index arrays for different types of features
print('Finding column indices for feature types...')
nominal_cols = np.where(feature_types == "nominal")[0]
integer_cols = np.where(feature_types == "integer")[0]
binary_cols = np.where(feature_types == "binary")[0]
float_cols = np.where(feature_types == "float")[0]

# arrays for names of the different types of features
nominal_names = feature_names[nominal_cols]
integer_names = feature_names[integer_cols]
binary_names = feature_names[binary_cols]
float_names = feature_names[float_cols]

print('Reading csv file...')
#dataframe = pandas.read_csv("UNSW.csv", header=None)
df = pd.read_csv("/content/drive/My Drive/UNSW.csv", header=None)

print('Preprocessing...')
print('Converting data...')
df[integer_cols] = df[integer_cols].apply(pd.to_numeric, errors='coerce')
df[binary_cols] = df[binary_cols].apply(pd.to_numeric, errors='coerce')
df[float_cols] = df[float_cols].apply(pd.to_numeric, errors='coerce')
df[48] = df[48].apply(pd.to_numeric, errors='coerce')
#dataframe[nominal_cols] = dataframe[nominal_cols].astype(str)

print('Replacing NaNs...')
df.loc[:,47] = df.loc[:,47].replace(np.nan,'normal', regex=True).apply(lambda x: x.strip().lower())
df.loc[:,binary_cols] = df.loc[:,binary_cols].replace(np.nan, 0, regex=True)
df.loc[:,37:39] = df.loc[:,37:39].replace(np.nan, 0, regex=True)
# dataframe.loc[:,float_cols] = dataframe.loc[:,float_cols].replace(np.nan, 0, regex=True)

print('Stripping nominal columns and setting them lower case...')
df.loc[:,nominal_cols] = df.loc[:,nominal_cols].applymap(lambda x: x.strip().lower())

print('Changing targets \'backdoors\' to \'backdoor\'...')
df.loc[:,47] = df.loc[:,47].replace('backdoors','backdoor', regex=True).apply(lambda x: x.strip().lower())

print('Adding column headers...')
col = [
    'Srcip',
    'Sport',
    'Dstip',
    'Dsport',
    'Proto',
    'State',
    'Dur',
    'sbytes',
    'dbytes',
    'Sttl',
    'Dttl',
    'Sloss',
    'dloss',
    'service',
    'sload',
    'dload',
    'spkts',
    'dpkts',
    'Swin',
    'Dwin',
    'Stcpb',
    'Dtcpb',
    'Smeansz',
    'Dmeansz',
    'trans_depth',
    'res_bdy_len',
    'Sjit',
    'Djit',
    'Stime',
    'Ltime',
    'Sintpkt',
    'Dintpkt',
    'Tcprtt',
    'Synack',
    'Ackdat',
    'is_sm_ips_ports',
    'ct_state_ttl',
    'ct_flw_http_mthd',
    'is_ftp_login',
    'ct_ftp_cmd',
    'ct_srv_src',
    'ct_srv_dst',
    'ct_dst_ltm',
    'ct_src_ltm',
    'ct_src_dport_ltm',
    'ct_dst_sport_ltm',
    'ct_dst_src_ltm',
    'attack_cat',
    'Label'
]
df.columns = col

print('Copying values...')
dataset = df.values

# display 5 rows
print('Printing 5 rows of the processed dataframe...')
df[0:5]
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>
# Downloading data from https://www.unsw.adfa.edu.au/unsw-canberra-cyber/cybersecurity/ADFA-NB15-Datasets/NUSW-NB15_features.csv
# 8192/4044 [============================================================] - 0s 0us/step
# Reading feature info...
# Finding column indices for feature types...
# Reading csv file...
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (1,3,39,47) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# Preprocessing...
# Converting data...
# Replacing NaNs...
# Stripping nominal columns and setting them lower case...
# Changing targets 'backdoors' to 'backdoor'...
# Adding column headers...
# Copying values...
# Printing 5 rows of the processed dataframe...
#         Srcip    Sport          Dstip  ...  ct_dst_src_ltm attack_cat Label
# 0  59.166.0.0   1390.0  149.171.126.6  ...               1     normal     0
# 1  59.166.0.0  33661.0  149.171.126.9  ...               2     normal     0
# 2  59.166.0.6   1464.0  149.171.126.7  ...               1     normal     0
# 3  59.166.0.5   3593.0  149.171.126.5  ...               1     normal     0
# 4  59.166.0.3  49664.0  149.171.126.0  ...               1     normal     0
#
# [5 rows x 49 columns]

# %% [markdown]
# ## **Transforming into numeric**

# %%
# Subsets of the dataset which have data that is only of the corresponding data type (nominal, integer etc)
# Columns don't include the target classes (the two last columns of the dataset)
print('Slicing dataset...')
nominal_x = dataset[:, nominal_cols][:,:]
integer_x = dataset[:, integer_cols][:,:].astype(np.float32)    
binary_x = dataset[:, binary_cols][:,:].astype(np.float32)
float_x = dataset[:, float_cols][:,:].astype(np.float32)

# Make nominal (textual) data binary vectors
print('Vectorizing nominal data...')
from sklearn.feature_extraction import DictVectorizer
v = DictVectorizer(sparse=False)
# D = [{'foo': 1, 'bar': 2}, {'foo': 3, 'baz': 1}]
D = map(lambda dataline: dict(zip(nominal_names, dataline)), nominal_x)
labeled_nominal_x = v.fit_transform(D).astype(np.float32)
del nominal_x

print('Concatenating X...')
X = np.concatenate((integer_x, labeled_nominal_x, float_x, binary_x), axis=1)

del integer_x
del labeled_nominal_x
del float_x
del binary_x

# Find rows that have NaNs
print('Removing NaNs if any...')
nan_indices = []
for feature_i in range(X.shape[1]):
    nan_indices.extend(list(np.where(np.isnan(X[:, feature_i]))[0]))
nan_indices = np.unique(nan_indices)

# Remove rows that have NaNs
X_no_nans = np.delete(X, nan_indices, axis=0)

del X

print('Normalizing X...')
normalized_X = normalize(X_no_nans, copy=False)

del X_no_nans


data_dim = normalized_X.shape
print('Data dimensions are', data_dim)

print('Creating target Y matrix...')
Y = np.delete(dataset[:, -2], nan_indices)
Y_A = np.delete(dataset[:, -1], nan_indices).astype(np.int16) # Is attack or not

del dataset

print('Vectorizing Y labels...')
D = [{'attack_cat': y} for y in Y]
labeled_Y = v.fit_transform(D)

del D

print('Done')
# Out:
# Slicing dataset...
# Vectorizing nominal data...
# Concatenating X...
# Removing NaNs if any...
# Normalizing X...
# Data dimensions are (2539739, 294)
# Creating target Y matrix...
# Vectorizing Y labels...
# Done

# %% [markdown]
# ## **Train the Neural Network**

# %%
import pandas as pd
import io
import requests
import numpy as np
import os
import timeit
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv1D, Flatten
from tensorflow.keras.callbacks import EarlyStopping
from keras import backend as K

#Custom Metrics
def recall_m(y_true, y_pred):
        true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
        possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
        recall = true_positives / (possible_positives + K.epsilon())
        return recall

def precision_m(y_true, y_pred):
        true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
        predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
        precision = true_positives / (predicted_positives + K.epsilon())
        return precision

def f1_m(y_true, y_pred):
    precision = precision_m(y_true, y_pred)
    recall = recall_m(y_true, y_pred)
    return 2*((precision*recall)/(precision+recall+K.epsilon()))

# Create a test/train split. 50% test
# Split into train/test
x_train, x_test, y_train, y_test = train_test_split(
    normalized_X, labeled_Y, test_size=0.5, random_state=42)

num_of_features = x_train.shape[1] #294 features
nb_classes = y_train.shape[1] #10 detected actions

# Reshaping x_train and x_test for efficient modelling
x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], 1))
x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], 1))

#Model
model = Sequential()

model.add(Conv1D(40, kernel_size=3, activation='relu', input_shape=(num_of_features,1)))
model.add(Conv1D(nb_classes, kernel_size=3))
model.add(Flatten())
model.add(Dense(nb_classes,activation='softmax'))

model.compile(optimizer='adam',loss='categorical_crossentropy', metrics=['accuracy', precision_m, recall_m, f1_m])

monitor = EarlyStopping(monitor='val_loss', min_delta=1e-5, patience=170, verbose=1, mode='auto')

startTime = timeit.default_timer()
history = model.fit(x_train,y_train,validation_data=(x_test,y_test),callbacks=[monitor],verbose=1,epochs=100,batch_size=1024)
elapsedTime = timeit.default_timer() - startTime

print("Time taken for the Network to train:",elapsedTime)
# Out:
# Train on 1269869 samples, validate on 1269870 samples
# Epoch 1/100
# 1269869/1269869 [==============================] - 70s 55us/sample - loss: 0.3751 - acc: 0.8712 - precision_m: 0.9337 - recall_m: 0.8006 - f1_m: 0.8600 - val_loss: 0.3454 - val_acc: 0.8737 - val_precision_m: 0.9711 - val_recall_m: 0.7835 - val_f1_m: 0.8672
# Epoch 2/100
# 1269869/1269869 [==============================] - 70s 55us/sample - loss: 0.3448 - acc: 0.8720 - precision_m: 0.9550 - recall_m: 0.7984 - f1_m: 0.8684 - val_loss: 0.3461 - val_acc: 0.8679 - val_precision_m: 0.8690 - val_recall_m: 0.8671 - val_f1_m: 0.8680
# Epoch 3/100
# 1269869/1269869 [==============================] - 69s 54us/sample - loss: 0.3442 - acc: 0.8724 - precision_m: 0.9549 - recall_m: 0.7987 - f1_m: 0.8685 - val_loss: 0.3436 - val_acc: 0.8679 - val_precision_m: 0.9711 - val_recall_m: 0.7836 - val_f1_m: 0.8673
# Epoch 4/100
# 1269869/1269869 [==============================] - 71s 56us/sample - loss: 0.3435 - acc: 0.8722 - precision_m: 0.9549 - recall_m: 0.7988 - f1_m: 0.8685 - val_loss: 0.3436 - val_acc: 0.8739 - val_precision_m: 0.9711 - val_recall_m: 0.7838 - val_f1_m: 0.8674
# Epoch 5/100
# 1269869/1269869 [==============================] - 72s 57us/sample - loss: 0.3422 - acc: 0.8723 - precision_m: 0.9571 - recall_m: 0.7968 - f1_m: 0.8684 - val_loss: 0.3414 - val_acc: 0.8679 - val_precision_m: 0.9712 - val_recall_m: 0.7837 - val_f1_m: 0.8674
# Epoch 6/100
# 1269869/1269869 [==============================] - 68s 54us/sample - loss: 0.3397 - acc: 0.8724 - precision_m: 0.9590 - recall_m: 0.7951 - f1_m: 0.8683 - val_loss: 0.3389 - val_acc: 0.8740 - val_precision_m: 0.8751 - val_recall_m: 0.8734 - val_f1_m: 0.8742
# Epoch 7/100
# 1269869/1269869 [==============================] - 68s 54us/sample - loss: 0.3356 - acc: 0.8726 - precision_m: 0.9590 - recall_m: 0.7951 - f1_m: 0.8684 - val_loss: 0.3329 - val_acc: 0.8741 - val_precision_m: 0.9712 - val_recall_m: 0.7839 - val_f1_m: 0.8675
# Epoch 8/100
# 1269869/1269869 [==============================] - 69s 54us/sample - loss: 0.3309 - acc: 0.8725 - precision_m: 0.9646 - recall_m: 0.7902 - f1_m: 0.8681 - val_loss: 0.3296 - val_acc: 0.8742 - val_precision_m: 0.9712 - val_recall_m: 0.7839 - val_f1_m: 0.8675
# Epoch 9/100
# 1269869/1269869 [==============================] - 69s 54us/sample - loss: 0.3278 - acc: 0.8729 - precision_m: 0.9617 - recall_m: 0.7928 - f1_m: 0.8682 - val_loss: 0.3265 - val_acc: 0.8741 - val_precision_m: 0.9720 - val_recall_m: 0.7831 - val_f1_m: 0.8674
# Epoch 10/100
# 1269869/1269869 [==============================] - 69s 54us/sample - loss: 0.3253 - acc: 0.8729 - precision_m: 0.9634 - recall_m: 0.7912 - f1_m: 0.8681 - val_loss: 0.3247 - val_acc: 0.8741 - val_precision_m: 0.8766 - val_recall_m: 0.8714 - val_f1_m: 0.8740
# Epoch 11/100
# 1269869/1269869 [==============================] - 69s 54us/sample - loss: 0.3229 - acc: 0.8731 - precision_m: 0.9641 - recall_m: 0.7911 - f1_m: 0.8682 - val_loss: 0.3221 - val_acc: 0.8743 - val_precision_m: 0.8757 - val_recall_m: 0.8729 - val_f1_m: 0.8743
# Epoch 12/100
# 1269869/1269869 [==============================] - 69s 55us/sample - loss: 0.3207 - acc: 0.8740 - precision_m: 0.9597 - recall_m: 0.7954 - f1_m: 0.8687 - val_loss: 0.3188 - val_acc: 0.8978 - val_precision_m: 0.9728 - val_recall_m: 0.7826 - val_f1_m: 0.8674
# Epoch 13/100
# 1269869/1269869 [==============================] - 69s 54us/sample - loss: 0.3183 - acc: 0.8755 - precision_m: 0.9599 - recall_m: 0.7960 - f1_m: 0.8692 - val_loss: 0.3171 - val_acc: 0.8747 - val_precision_m: 0.9723 - val_recall_m: 0.7835 - val_f1_m: 0.8677
# Epoch 14/100
# 1269869/1269869 [==============================] - 69s 55us/sample - loss: 0.3158 - acc: 0.8786 - precision_m: 0.9593 - recall_m: 0.7976 - f1_m: 0.8699 - val_loss: 0.3148 - val_acc: 0.8747 - val_precision_m: 0.9712 - val_recall_m: 0.7845 - val_f1_m: 0.8679
# Epoch 15/100
# 1269869/1269869 [==============================] - 68s 54us/sample - loss: 0.3132 - acc: 0.8841 - precision_m: 0.9590 - recall_m: 0.7995 - f1_m: 0.8711 - val_loss: 0.3113 - val_acc: 0.8955 - val_precision_m: 0.9727 - val_recall_m: 0.7844 - val_f1_m: 0.8684
# Epoch 16/100
# 1269869/1269869 [==============================] - 69s 54us/sample - loss: 0.3104 - acc: 0.8892 - precision_m: 0.9517 - recall_m: 0.8156 - f1_m: 0.8775 - val_loss: 0.3109 - val_acc: 0.8685 - val_precision_m: 0.9575 - val_recall_m: 0.8128 - val_f1_m: 0.8792
# Epoch 17/100
# 1269869/1269869 [==============================] - 69s 55us/sample - loss: 0.3072 - acc: 0.8900 - precision_m: 0.9404 - recall_m: 0.8357 - f1_m: 0.8841 - val_loss: 0.3058 - val_acc: 0.8991 - val_precision_m: 0.9087 - val_recall_m: 0.8728 - val_f1_m: 0.8904
# Epoch 18/100
# 1269869/1269869 [==============================] - 71s 56us/sample - loss: 0.3041 - acc: 0.8884 - precision_m: 0.9241 - recall_m: 0.8523 - f1_m: 0.8861 - val_loss: 0.3027 - val_acc: 0.8861 - val_precision_m: 0.9098 - val_recall_m: 0.8617 - val_f1_m: 0.8851
# Epoch 19/100
# 1269869/1269869 [==============================] - 70s 55us/sample - loss: 0.3014 - acc: 0.8870 - precision_m: 0.9091 - recall_m: 0.8636 - f1_m: 0.8855 - val_loss: 0.3002 - val_acc: 0.8842 - val_precision_m: 0.8929 - val_recall_m: 0.8659 - val_f1_m: 0.8792
# Epoch 20/100
# 1269869/1269869 [==============================] - 71s 56us/sample - loss: 0.2997 - acc: 0.8860 - precision_m: 0.9023 - recall_m: 0.8682 - f1_m: 0.8848 - val_loss: 0.2993 - val_acc: 0.8844 - val_precision_m: 0.8916 - val_recall_m: 0.8711 - val_f1_m: 0.8812
# Epoch 21/100
# 1269869/1269869 [==============================] - 70s 55us/sample - loss: 0.2983 - acc: 0.8859 - precision_m: 0.8982 - recall_m: 0.8709 - f1_m: 0.8843 - val_loss: 0.2968 - val_acc: 0.8862 - val_precision_m: 0.8907 - val_recall_m: 0.8665 - val_f1_m: 0.8784
# Epoch 22/100
# 1269869/1269869 [==============================] - 71s 56us/sample - loss: 0.2973 - acc: 0.8859 - precision_m: 0.8979 - recall_m: 0.8714 - f1_m: 0.8843 - val_loss: 0.2968 - val_acc: 0.8856 - val_precision_m: 0.9008 - val_recall_m: 0.8696 - val_f1_m: 0.8849
# Epoch 23/100
# 1269869/1269869 [==============================] - 69s 54us/sample - loss: 0.2962 - acc: 0.8859 - precision_m: 0.8981 - recall_m: 0.8716 - f1_m: 0.8845 - val_loss: 0.2980 - val_acc: 0.8865 - val_precision_m: 0.8997 - val_recall_m: 0.8753 - val_f1_m: 0.8874
# Epoch 24/100
# 1269869/1269869 [==============================] - 70s 55us/sample - loss: 0.2952 - acc: 0.8861 - precision_m: 0.8977 - recall_m: 0.8722 - f1_m: 0.8847 - val_loss: 0.2963 - val_acc: 0.8886 - val_precision_m: 0.9005 - val_recall_m: 0.8744 - val_f1_m: 0.8872
# Epoch 25/100
# 1269869/1269869 [==============================] - 69s 54us/sample - loss: 0.2942 - acc: 0.8863 - precision_m: 0.8980 - recall_m: 0.8724 - f1_m: 0.8849 - val_loss: 0.2937 - val_acc: 0.8847 - val_precision_m: 0.8932 - val_recall_m: 0.8665 - val_f1_m: 0.8797
# Epoch 26/100
# 1269869/1269869 [==============================] - 69s 54us/sample - loss: 0.2935 - acc: 0.8864 - precision_m: 0.8983 - recall_m: 0.8721 - f1_m: 0.8849 - val_loss: 0.2933 - val_acc: 0.8837 - val_precision_m: 0.8918 - val_recall_m: 0.8718 - val_f1_m: 0.8817
# Epoch 27/100
# 1269869/1269869 [==============================] - 70s 55us/sample - loss: 0.2928 - acc: 0.8864 - precision_m: 0.8983 - recall_m: 0.8726 - f1_m: 0.8851 - val_loss: 0.2921 - val_acc: 0.8812 - val_precision_m: 0.9068 - val_recall_m: 0.8661 - val_f1_m: 0.8860
# Epoch 28/100
# 1269869/1269869 [==============================] - 69s 54us/sample - loss: 0.2919 - acc: 0.8865 - precision_m: 0.8977 - recall_m: 0.8735 - f1_m: 0.8853 - val_loss: 0.2925 - val_acc: 0.8885 - val_precision_m: 0.8993 - val_recall_m: 0.8763 - val_f1_m: 0.8876
# Epoch 29/100
# 1269869/1269869 [==============================] - 68s 54us/sample - loss: 0.2913 - acc: 0.8866 - precision_m: 0.8983 - recall_m: 0.8736 - f1_m: 0.8857 - val_loss: 0.2921 - val_acc: 0.8813 - val_precision_m: 0.9462 - val_recall_m: 0.8184 - val_f1_m: 0.8776
# Epoch 30/100
# 1269869/1269869 [==============================] - 68s 54us/sample - loss: 0.2904 - acc: 0.8868 - precision_m: 0.8976 - recall_m: 0.8751 - f1_m: 0.8861 - val_loss: 0.2893 - val_acc: 0.8867 - val_precision_m: 0.8918 - val_recall_m: 0.8778 - val_f1_m: 0.8847
# Epoch 31/100
# 1269869/1269869 [==============================] - 72s 56us/sample - loss: 0.2899 - acc: 0.8868 - precision_m: 0.8988 - recall_m: 0.8746 - f1_m: 0.8864 - val_loss: 0.2887 - val_acc: 0.8839 - val_precision_m: 0.8912 - val_recall_m: 0.8785 - val_f1_m: 0.8848
# Epoch 32/100
# 1269869/1269869 [==============================] - 69s 55us/sample - loss: 0.2892 - acc: 0.8869 - precision_m: 0.8989 - recall_m: 0.8753 - f1_m: 0.8868 - val_loss: 0.2903 - val_acc: 0.8849 - val_precision_m: 0.9328 - val_recall_m: 0.8637 - val_f1_m: 0.8969
# Epoch 33/100
# 1269869/1269869 [==============================] - 69s 55us/sample - loss: 0.2885 - acc: 0.8870 - precision_m: 0.8979 - recall_m: 0.8765 - f1_m: 0.8870 - val_loss: 0.2888 - val_acc: 0.8886 - val_precision_m: 0.9001 - val_recall_m: 0.8776 - val_f1_m: 0.8887
# Epoch 34/100
# 1269869/1269869 [==============================] - 69s 54us/sample - loss: 0.2878 - acc: 0.8873 - precision_m: 0.8983 - recall_m: 0.8769 - f1_m: 0.8873 - val_loss: 0.2885 - val_acc: 0.8972 - val_precision_m: 0.8990 - val_recall_m: 0.8905 - val_f1_m: 0.8947
# Epoch 35/100
# 1269869/1269869 [==============================] - 69s 54us/sample - loss: 0.2872 - acc: 0.8873 - precision_m: 0.9003 - recall_m: 0.8760 - f1_m: 0.8878 - val_loss: 0.2868 - val_acc: 0.8864 - val_precision_m: 0.8931 - val_recall_m: 0.8798 - val_f1_m: 0.8864
# Epoch 36/100
# 1269869/1269869 [==============================] - 70s 55us/sample - loss: 0.2864 - acc: 0.8874 - precision_m: 0.8992 - recall_m: 0.8779 - f1_m: 0.8883 - val_loss: 0.2855 - val_acc: 0.8867 - val_precision_m: 0.8926 - val_recall_m: 0.8813 - val_f1_m: 0.8869
# Epoch 37/100
# 1269869/1269869 [==============================] - 70s 56us/sample - loss: 0.2858 - acc: 0.8876 - precision_m: 0.9007 - recall_m: 0.8780 - f1_m: 0.8890 - val_loss: 0.2861 - val_acc: 0.8979 - val_precision_m: 0.9000 - val_recall_m: 0.8803 - val_f1_m: 0.8900
# Epoch 38/100
# 1269869/1269869 [==============================] - 69s 54us/sample - loss: 0.2849 - acc: 0.8878 - precision_m: 0.9010 - recall_m: 0.8787 - f1_m: 0.8896 - val_loss: 0.2861 - val_acc: 0.8971 - val_precision_m: 0.9044 - val_recall_m: 0.8902 - val_f1_m: 0.8972
# Epoch 39/100
# 1269869/1269869 [==============================] - 68s 53us/sample - loss: 0.2843 - acc: 0.8880 - precision_m: 0.9016 - recall_m: 0.8797 - f1_m: 0.8904 - val_loss: 0.2834 - val_acc: 0.8890 - val_precision_m: 0.8913 - val_recall_m: 0.8846 - val_f1_m: 0.8880
# Epoch 40/100
# 1269869/1269869 [==============================] - 69s 54us/sample - loss: 0.2836 - acc: 0.8881 - precision_m: 0.9025 - recall_m: 0.8808 - f1_m: 0.8914 - val_loss: 0.2831 - val_acc: 0.8867 - val_precision_m: 0.8950 - val_recall_m: 0.8788 - val_f1_m: 0.8868
# Epoch 41/100
# 1269869/1269869 [==============================] - 68s 54us/sample - loss: 0.2827 - acc: 0.8886 - precision_m: 0.9044 - recall_m: 0.8803 - f1_m: 0.8920 - val_loss: 0.2822 - val_acc: 0.8853 - val_precision_m: 0.9126 - val_recall_m: 0.8771 - val_f1_m: 0.8945
# Epoch 42/100
# 1269869/1269869 [==============================] - 68s 53us/sample - loss: 0.2817 - acc: 0.8890 - precision_m: 0.9079 - recall_m: 0.8806 - f1_m: 0.8939 - val_loss: 0.2810 - val_acc: 0.8982 - val_precision_m: 0.9036 - val_recall_m: 0.8815 - val_f1_m: 0.8924
# Epoch 43/100
# 1269869/1269869 [==============================] - 67s 53us/sample - loss: 0.2805 - acc: 0.8894 - precision_m: 0.9095 - recall_m: 0.8818 - f1_m: 0.8953 - val_loss: 0.2807 - val_acc: 0.8889 - val_precision_m: 0.8934 - val_recall_m: 0.8826 - val_f1_m: 0.8880
# Epoch 44/100
# 1269869/1269869 [==============================] - 68s 54us/sample - loss: 0.2789 - acc: 0.8903 - precision_m: 0.9136 - recall_m: 0.8826 - f1_m: 0.8977 - val_loss: 0.2785 - val_acc: 0.8871 - val_precision_m: 0.9090 - val_recall_m: 0.8835 - val_f1_m: 0.8961
# Epoch 45/100
# 1269869/1269869 [==============================] - 69s 54us/sample - loss: 0.2772 - acc: 0.8912 - precision_m: 0.9185 - recall_m: 0.8835 - f1_m: 0.9006 - val_loss: 0.2764 - val_acc: 0.8982 - val_precision_m: 0.9047 - val_recall_m: 0.8853 - val_f1_m: 0.8949
# Epoch 46/100
# 1269869/1269869 [==============================] - 68s 53us/sample - loss: 0.2750 - acc: 0.8932 - precision_m: 0.9239 - recall_m: 0.8846 - f1_m: 0.9037 - val_loss: 0.2747 - val_acc: 0.9029 - val_precision_m: 0.9043 - val_recall_m: 0.8916 - val_f1_m: 0.8979
# Epoch 47/100
# 1269869/1269869 [==============================] - 68s 53us/sample - loss: 0.2728 - acc: 0.8961 - precision_m: 0.9298 - recall_m: 0.8860 - f1_m: 0.9073 - val_loss: 0.2703 - val_acc: 0.8897 - val_precision_m: 0.9369 - val_recall_m: 0.8840 - val_f1_m: 0.9097
# Epoch 48/100
# 1269869/1269869 [==============================] - 68s 53us/sample - loss: 0.2698 - acc: 0.9024 - precision_m: 0.9354 - recall_m: 0.8880 - f1_m: 0.9110 - val_loss: 0.2675 - val_acc: 0.9149 - val_precision_m: 0.9424 - val_recall_m: 0.8853 - val_f1_m: 0.9129
# Epoch 49/100
# 1269869/1269869 [==============================] - 67s 53us/sample - loss: 0.2664 - acc: 0.9124 - precision_m: 0.9406 - recall_m: 0.8908 - f1_m: 0.9149 - val_loss: 0.2668 - val_acc: 0.9147 - val_precision_m: 0.9563 - val_recall_m: 0.8815 - val_f1_m: 0.9174
# Epoch 50/100
# 1269869/1269869 [==============================] - 68s 54us/sample - loss: 0.2635 - acc: 0.9214 - precision_m: 0.9449 - recall_m: 0.8944 - f1_m: 0.9189 - val_loss: 0.2628 - val_acc: 0.9310 - val_precision_m: 0.9563 - val_recall_m: 0.8867 - val_f1_m: 0.9202
# Epoch 51/100
# 1269869/1269869 [==============================] - 67s 53us/sample - loss: 0.2595 - acc: 0.9278 - precision_m: 0.9490 - recall_m: 0.9029 - f1_m: 0.9253 - val_loss: 0.2598 - val_acc: 0.9078 - val_precision_m: 0.9299 - val_recall_m: 0.9013 - val_f1_m: 0.9154
# Epoch 52/100
# 1269869/1269869 [==============================] - 68s 53us/sample - loss: 0.2553 - acc: 0.9319 - precision_m: 0.9517 - recall_m: 0.9146 - f1_m: 0.9328 - val_loss: 0.2540 - val_acc: 0.9341 - val_precision_m: 0.9484 - val_recall_m: 0.9245 - val_f1_m: 0.9363
# Epoch 53/100
# 1269869/1269869 [==============================] - 67s 53us/sample - loss: 0.2509 - acc: 0.9337 - precision_m: 0.9538 - recall_m: 0.9216 - f1_m: 0.9374 - val_loss: 0.2516 - val_acc: 0.9300 - val_precision_m: 0.9568 - val_recall_m: 0.9142 - val_f1_m: 0.9350
# Epoch 54/100
# 1269869/1269869 [==============================] - 68s 54us/sample - loss: 0.2461 - acc: 0.9355 - precision_m: 0.9547 - recall_m: 0.9249 - f1_m: 0.9395 - val_loss: 0.2438 - val_acc: 0.9313 - val_precision_m: 0.9446 - val_recall_m: 0.9233 - val_f1_m: 0.9338
# Epoch 55/100
# 1269869/1269869 [==============================] - 67s 53us/sample - loss: 0.2414 - acc: 0.9368 - precision_m: 0.9558 - recall_m: 0.9264 - f1_m: 0.9408 - val_loss: 0.2381 - val_acc: 0.9311 - val_precision_m: 0.9545 - val_recall_m: 0.9246 - val_f1_m: 0.9393
# Epoch 56/100
# 1269869/1269869 [==============================] - 67s 53us/sample - loss: 0.2368 - acc: 0.9375 - precision_m: 0.9567 - recall_m: 0.9274 - f1_m: 0.9418 - val_loss: 0.2346 - val_acc: 0.9347 - val_precision_m: 0.9523 - val_recall_m: 0.9288 - val_f1_m: 0.9404
# Epoch 57/100
# 1269869/1269869 [==============================] - 67s 52us/sample - loss: 0.2318 - acc: 0.9384 - precision_m: 0.9577 - recall_m: 0.9279 - f1_m: 0.9425 - val_loss: 0.2287 - val_acc: 0.9402 - val_precision_m: 0.9569 - val_recall_m: 0.9250 - val_f1_m: 0.9407
# Epoch 58/100
# 1269869/1269869 [==============================] - 70s 55us/sample - loss: 0.2269 - acc: 0.9392 - precision_m: 0.9581 - recall_m: 0.9290 - f1_m: 0.9433 - val_loss: 0.2241 - val_acc: 0.9426 - val_precision_m: 0.9650 - val_recall_m: 0.9243 - val_f1_m: 0.9442
# Epoch 59/100
# 1269869/1269869 [==============================] - 69s 54us/sample - loss: 0.2225 - acc: 0.9399 - precision_m: 0.9585 - recall_m: 0.9300 - f1_m: 0.9440 - val_loss: 0.2200 - val_acc: 0.9384 - val_precision_m: 0.9513 - val_recall_m: 0.9307 - val_f1_m: 0.9409
# Epoch 60/100
# 1269869/1269869 [==============================] - 68s 54us/sample - loss: 0.2181 - acc: 0.9402 - precision_m: 0.9575 - recall_m: 0.9302 - f1_m: 0.9437 - val_loss: 0.2158 - val_acc: 0.9377 - val_precision_m: 0.9479 - val_recall_m: 0.9288 - val_f1_m: 0.9383
# Epoch 61/100
# 1269869/1269869 [==============================] - 68s 54us/sample - loss: 0.2141 - acc: 0.9407 - precision_m: 0.9573 - recall_m: 0.9305 - f1_m: 0.9437 - val_loss: 0.2112 - val_acc: 0.9420 - val_precision_m: 0.9600 - val_recall_m: 0.9293 - val_f1_m: 0.9444
# Epoch 62/100
# 1269869/1269869 [==============================] - 68s 54us/sample - loss: 0.2105 - acc: 0.9412 - precision_m: 0.9577 - recall_m: 0.9313 - f1_m: 0.9443 - val_loss: 0.2088 - val_acc: 0.9383 - val_precision_m: 0.9531 - val_recall_m: 0.9311 - val_f1_m: 0.9420
# Epoch 63/100
# 1269869/1269869 [==============================] - 69s 54us/sample - loss: 0.2107 - acc: 0.9417 - precision_m: 0.9584 - recall_m: 0.9319 - f1_m: 0.9450 - val_loss: 0.2194 - val_acc: 0.9437 - val_precision_m: 0.9633 - val_recall_m: 0.9309 - val_f1_m: 0.9468
# Epoch 64/100
# 1269869/1269869 [==============================] - 69s 54us/sample - loss: 0.2161 - acc: 0.9414 - precision_m: 0.9598 - recall_m: 0.9314 - f1_m: 0.9454 - val_loss: 0.2142 - val_acc: 0.9382 - val_precision_m: 0.9582 - val_recall_m: 0.9297 - val_f1_m: 0.9437
# Epoch 65/100
# 1269869/1269869 [==============================] - 70s 55us/sample - loss: 0.2124 - acc: 0.9418 - precision_m: 0.9590 - recall_m: 0.9319 - f1_m: 0.9452 - val_loss: 0.2135 - val_acc: 0.9381 - val_precision_m: 0.9600 - val_recall_m: 0.9299 - val_f1_m: 0.9447
# Epoch 66/100
# 1269869/1269869 [==============================] - 69s 54us/sample - loss: 0.2086 - acc: 0.9422 - precision_m: 0.9592 - recall_m: 0.9325 - f1_m: 0.9457 - val_loss: 0.2059 - val_acc: 0.9433 - val_precision_m: 0.9594 - val_recall_m: 0.9386 - val_f1_m: 0.9489
# Epoch 67/100
# 1269869/1269869 [==============================] - 69s 54us/sample - loss: 0.2054 - acc: 0.9429 - precision_m: 0.9592 - recall_m: 0.9337 - f1_m: 0.9463 - val_loss: 0.2044 - val_acc: 0.9431 - val_precision_m: 0.9587 - val_recall_m: 0.9387 - val_f1_m: 0.9486
# Epoch 68/100
# 1269869/1269869 [==============================] - 70s 55us/sample - loss: 0.2028 - acc: 0.9440 - precision_m: 0.9592 - recall_m: 0.9346 - f1_m: 0.9467 - val_loss: 0.2028 - val_acc: 0.9396 - val_precision_m: 0.9592 - val_recall_m: 0.9328 - val_f1_m: 0.9458
# Epoch 69/100
# 1269869/1269869 [==============================] - 68s 54us/sample - loss: 0.2001 - acc: 0.9447 - precision_m: 0.9596 - recall_m: 0.9351 - f1_m: 0.9472 - val_loss: 0.1997 - val_acc: 0.9501 - val_precision_m: 0.9602 - val_recall_m: 0.9454 - val_f1_m: 0.9527
# Epoch 70/100
# 1269869/1269869 [==============================] - 69s 54us/sample - loss: 0.2239 - acc: 0.9436 - precision_m: 0.9626 - recall_m: 0.9254 - f1_m: 0.9435 - val_loss: 0.2634 - val_acc: 0.9323 - val_precision_m: 0.9641 - val_recall_m: 0.9189 - val_f1_m: 0.9409
# Epoch 71/100
# 1269869/1269869 [==============================] - 69s 54us/sample - loss: 0.2599 - acc: 0.9428 - precision_m: 0.9702 - recall_m: 0.9214 - f1_m: 0.9451 - val_loss: 0.2570 - val_acc: 0.9323 - val_precision_m: 0.9556 - val_recall_m: 0.9212 - val_f1_m: 0.9381
# Epoch 72/100
# 1269869/1269869 [==============================] - 71s 56us/sample - loss: 0.2539 - acc: 0.9431 - precision_m: 0.9701 - recall_m: 0.9257 - f1_m: 0.9474 - val_loss: 0.2512 - val_acc: 0.9444 - val_precision_m: 0.9689 - val_recall_m: 0.9286 - val_f1_m: 0.9483
# Epoch 73/100
# 1269869/1269869 [==============================] - 69s 54us/sample - loss: 0.2481 - acc: 0.9434 - precision_m: 0.9695 - recall_m: 0.9287 - f1_m: 0.9486 - val_loss: 0.2460 - val_acc: 0.9446 - val_precision_m: 0.9715 - val_recall_m: 0.9350 - val_f1_m: 0.9529
# Epoch 74/100
# 1269869/1269869 [==============================] - 68s 54us/sample - loss: 0.2421 - acc: 0.9433 - precision_m: 0.9691 - recall_m: 0.9299 - f1_m: 0.9491 - val_loss: 0.2396 - val_acc: 0.9469 - val_precision_m: 0.9750 - val_recall_m: 0.9324 - val_f1_m: 0.9532
# Epoch 75/100
# 1269869/1269869 [==============================] - 68s 54us/sample - loss: 0.2362 - acc: 0.9431 - precision_m: 0.9680 - recall_m: 0.9313 - f1_m: 0.9493 - val_loss: 0.2338 - val_acc: 0.9516 - val_precision_m: 0.9739 - val_recall_m: 0.9358 - val_f1_m: 0.9544
# Epoch 76/100
# 1269869/1269869 [==============================] - 68s 54us/sample - loss: 0.2298 - acc: 0.9434 - precision_m: 0.9677 - recall_m: 0.9324 - f1_m: 0.9497 - val_loss: 0.2269 - val_acc: 0.9441 - val_precision_m: 0.9648 - val_recall_m: 0.9310 - val_f1_m: 0.9476
# Epoch 77/100
# 1269869/1269869 [==============================] - 69s 54us/sample - loss: 0.2243 - acc: 0.9434 - precision_m: 0.9673 - recall_m: 0.9330 - f1_m: 0.9499 - val_loss: 0.2254 - val_acc: 0.9506 - val_precision_m: 0.9754 - val_recall_m: 0.9335 - val_f1_m: 0.9540
# Epoch 78/100
# 1269869/1269869 [==============================] - 68s 54us/sample - loss: 0.2188 - acc: 0.9436 - precision_m: 0.9668 - recall_m: 0.9332 - f1_m: 0.9497 - val_loss: 0.2180 - val_acc: 0.9435 - val_precision_m: 0.9642 - val_recall_m: 0.9385 - val_f1_m: 0.9512
# Epoch 79/100
# 1269869/1269869 [==============================] - 68s 54us/sample - loss: 0.2138 - acc: 0.9440 - precision_m: 0.9667 - recall_m: 0.9338 - f1_m: 0.9500 - val_loss: 0.2105 - val_acc: 0.9437 - val_precision_m: 0.9660 - val_recall_m: 0.9356 - val_f1_m: 0.9506
# Epoch 80/100
# 1269869/1269869 [==============================] - 68s 54us/sample - loss: 0.2089 - acc: 0.9442 - precision_m: 0.9667 - recall_m: 0.9348 - f1_m: 0.9504 - val_loss: 0.2055 - val_acc: 0.9433 - val_precision_m: 0.9690 - val_recall_m: 0.9371 - val_f1_m: 0.9527
# Epoch 81/100
# 1269869/1269869 [==============================] - 55s 43us/sample - loss: 0.2045 - acc: 0.9445 - precision_m: 0.9664 - recall_m: 0.9358 - f1_m: 0.9509 - val_loss: 0.2017 - val_acc: 0.9431 - val_precision_m: 0.9671 - val_recall_m: 0.9346 - val_f1_m: 0.9506
# Epoch 82/100
# 1269869/1269869 [==============================] - 56s 44us/sample - loss: 0.2002 - acc: 0.9448 - precision_m: 0.9667 - recall_m: 0.9366 - f1_m: 0.9514 - val_loss: 0.1975 - val_acc: 0.9428 - val_precision_m: 0.9667 - val_recall_m: 0.9370 - val_f1_m: 0.9516
# Epoch 83/100
# 1269869/1269869 [==============================] - 56s 44us/sample - loss: 0.1966 - acc: 0.9456 - precision_m: 0.9668 - recall_m: 0.9369 - f1_m: 0.9516 - val_loss: 0.1953 - val_acc: 0.9424 - val_precision_m: 0.9662 - val_recall_m: 0.9341 - val_f1_m: 0.9499
# Epoch 84/100
# 1269869/1269869 [==============================] - 56s 44us/sample - loss: 0.1933 - acc: 0.9465 - precision_m: 0.9672 - recall_m: 0.9370 - f1_m: 0.9518 - val_loss: 0.1922 - val_acc: 0.9428 - val_precision_m: 0.9656 - val_recall_m: 0.9347 - val_f1_m: 0.9498
# Epoch 85/100
# 1269869/1269869 [==============================] - 55s 44us/sample - loss: 0.1904 - acc: 0.9469 - precision_m: 0.9674 - recall_m: 0.9368 - f1_m: 0.9518 - val_loss: 0.1885 - val_acc: 0.9496 - val_precision_m: 0.9668 - val_recall_m: 0.9374 - val_f1_m: 0.9518
# Epoch 86/100
# 1269869/1269869 [==============================] - 59s 46us/sample - loss: 0.1875 - acc: 0.9480 - precision_m: 0.9677 - recall_m: 0.9367 - f1_m: 0.9519 - val_loss: 0.1851 - val_acc: 0.9426 - val_precision_m: 0.9665 - val_recall_m: 0.9369 - val_f1_m: 0.9515
# Epoch 87/100
# 1269869/1269869 [==============================] - 56s 44us/sample - loss: 0.1848 - acc: 0.9485 - precision_m: 0.9681 - recall_m: 0.9366 - f1_m: 0.9521 - val_loss: 0.1844 - val_acc: 0.9485 - val_precision_m: 0.9684 - val_recall_m: 0.9351 - val_f1_m: 0.9514
# Epoch 88/100
# 1269869/1269869 [==============================] - 56s 44us/sample - loss: 0.1826 - acc: 0.9488 - precision_m: 0.9685 - recall_m: 0.9368 - f1_m: 0.9524 - val_loss: 0.1818 - val_acc: 0.9492 - val_precision_m: 0.9670 - val_recall_m: 0.9368 - val_f1_m: 0.9517
# Epoch 89/100
# 1269869/1269869 [==============================] - 56s 44us/sample - loss: 0.1803 - acc: 0.9492 - precision_m: 0.9689 - recall_m: 0.9373 - f1_m: 0.9528 - val_loss: 0.1777 - val_acc: 0.9507 - val_precision_m: 0.9685 - val_recall_m: 0.9370 - val_f1_m: 0.9525
# Epoch 90/100
# 1269869/1269869 [==============================] - 56s 44us/sample - loss: 0.1786 - acc: 0.9492 - precision_m: 0.9691 - recall_m: 0.9387 - f1_m: 0.9537 - val_loss: 0.1769 - val_acc: 0.9499 - val_precision_m: 0.9681 - val_recall_m: 0.9378 - val_f1_m: 0.9527
# Epoch 91/100
# 1269869/1269869 [==============================] - 56s 44us/sample - loss: 0.1767 - acc: 0.9493 - precision_m: 0.9694 - recall_m: 0.9406 - f1_m: 0.9548 - val_loss: 0.1743 - val_acc: 0.9501 - val_precision_m: 0.9712 - val_recall_m: 0.9436 - val_f1_m: 0.9572
# Epoch 92/100
# 1269869/1269869 [==============================] - 57s 45us/sample - loss: 0.1747 - acc: 0.9494 - precision_m: 0.9700 - recall_m: 0.9417 - f1_m: 0.9556 - val_loss: 0.1738 - val_acc: 0.9495 - val_precision_m: 0.9690 - val_recall_m: 0.9356 - val_f1_m: 0.9520
# Epoch 93/100
# 1269869/1269869 [==============================] - 56s 44us/sample - loss: 0.1730 - acc: 0.9494 - precision_m: 0.9702 - recall_m: 0.9424 - f1_m: 0.9561 - val_loss: 0.1726 - val_acc: 0.9491 - val_precision_m: 0.9725 - val_recall_m: 0.9427 - val_f1_m: 0.9574
# Epoch 94/100
# 1269869/1269869 [==============================] - 55s 43us/sample - loss: 0.1711 - acc: 0.9495 - precision_m: 0.9707 - recall_m: 0.9429 - f1_m: 0.9566 - val_loss: 0.1752 - val_acc: 0.9500 - val_precision_m: 0.9678 - val_recall_m: 0.9355 - val_f1_m: 0.9514
# Epoch 95/100
# 1269869/1269869 [==============================] - 55s 44us/sample - loss: 0.1698 - acc: 0.9496 - precision_m: 0.9710 - recall_m: 0.9430 - f1_m: 0.9568 - val_loss: 0.1701 - val_acc: 0.9489 - val_precision_m: 0.9693 - val_recall_m: 0.9426 - val_f1_m: 0.9558
# Epoch 96/100
# 1269869/1269869 [==============================] - 55s 43us/sample - loss: 0.1686 - acc: 0.9497 - precision_m: 0.9715 - recall_m: 0.9431 - f1_m: 0.9570 - val_loss: 0.1674 - val_acc: 0.9501 - val_precision_m: 0.9725 - val_recall_m: 0.9441 - val_f1_m: 0.9581
# Epoch 97/100
# 1269869/1269869 [==============================] - 56s 44us/sample - loss: 0.1670 - acc: 0.9498 - precision_m: 0.9720 - recall_m: 0.9431 - f1_m: 0.9573 - val_loss: 0.1640 - val_acc: 0.9499 - val_precision_m: 0.9742 - val_recall_m: 0.9426 - val_f1_m: 0.9581
# Epoch 98/100
# 1269869/1269869 [==============================] - 55s 43us/sample - loss: 0.1657 - acc: 0.9500 - precision_m: 0.9723 - recall_m: 0.9431 - f1_m: 0.9575 - val_loss: 0.1636 - val_acc: 0.9518 - val_precision_m: 0.9742 - val_recall_m: 0.9432 - val_f1_m: 0.9585
# Epoch 99/100
# 1269869/1269869 [==============================] - 55s 44us/sample - loss: 0.1646 - acc: 0.9506 - precision_m: 0.9725 - recall_m: 0.9431 - f1_m: 0.9576 - val_loss: 0.1627 - val_acc: 0.9517 - val_precision_m: 0.9730 - val_recall_m: 0.9442 - val_f1_m: 0.9584
# Epoch 100/100
# 1269869/1269869 [==============================] - 55s 44us/sample - loss: 0.1768 - acc: 0.9495 - precision_m: 0.9707 - recall_m: 0.9419 - f1_m: 0.9561 - val_loss: 0.1655 - val_acc: 0.9506 - val_precision_m: 0.9743 - val_recall_m: 0.9419 - val_f1_m: 0.9578
# Time taken for the Network to train: 6627.463656517

# %% [markdown]
# ## **Plotting & Evaluating Metrics**

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score

#Evaluating
print("Evaluating...")
loss, accuracy, precision, recall, f1_score = model.evaluate(x_test, y_test, verbose=0, batch_size=1024)

print("Plotting the metrics...")
plt.rcParams["figure.figsize"] = [6,4]

# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()
print('Loss: %.2f%%' % (loss*100))

# Plot training & validation accuracy values
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()
print('Accuracy: %.2f%%' % (accuracy*100))

# Plot training & validation precision values
plt.plot(history.history['precision_m'])
plt.plot(history.history['val_precision_m'])
plt.title('Model Precision')
plt.ylabel('Precision')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()
print('Precision: %.2f%%' % (precision*100))

# Plot training & validation recall values
plt.plot(history.history['recall_m'])
plt.plot(history.history['val_recall_m'])
plt.title('Model Recall')
plt.ylabel('Recall')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()
print('Recall: %.2f%%' % (recall*100))

# Plot training & validation f1 score values
plt.plot(history.history['f1_m'])
plt.plot(history.history['val_f1_m'])
plt.title('Model F1 score')
plt.ylabel('F1 Score')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()
print('F1 Score: %.2f%%' % (f1_score*100))


# Final Score
print('\nFinal Score...')
y_p = model.predict(x_test)
y_pred = np.argmax(y_p,axis=1) #Return a 1D binary vector indicating the ID of the mac number in the row
y_eval = np.argmax(y_test,axis=1) #Return a 1D binary vector indicating the ID of the mac number in the row
score = accuracy_score(y_eval, y_pred)
print('Validation/Final Score: %.2f%%' % (score*100))
# Out:
# Evaluating...
# Plotting the metrics...
# Loss: 16.55%
# Accuracy: 95.06%
# Precision: 97.43%
# Recall: 94.18%
# F1 Score: 95.78%
#
# Final Score...
# Validation/Final Score: 95.06%

# %% [markdown]
# ## **Confusion Matrix**

# %%
# Measure accuracy
from sklearn.metrics import confusion_matrix
import itertools
import sys

# Confusion Matrix
def plot_confusion_matrix(cm, labels, classes, normalize=False, title='Confusion matrix', cmap=plt.cm.Greys):
    # This function prints and plots the confusion matrix. Normalization can be applied by setting `normalize=True`.
    plt.rcParams["figure.figsize"] = [10,10]
    plt.figure()
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')
    print(cm)

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    if labels is not None:
        tick_marks = np.arange(len(labels))
        plt.xticks(tick_marks, labels, rotation=60)
        plt.yticks(tick_marks, labels)
    else:
        tick_marks = np.arange(len(classes))
        plt.xticks(tick_marks, classes, rotation=45)
        plt.yticks(tick_marks, classes)

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        if normalize:
            plt.text(j, i, "{0:.4f}".format(cm[i, j]), horizontalalignment="center", color="white" if cm[i, j] > thresh else "black")
        else:
            plt.text(j, i, "{0:.0f}".format(cm[i, j]), horizontalalignment="center", color="white" if cm[i, j] > thresh else "black")
    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.show()

labels = ['Normal', 'Fuzzers', 'Analysis', 'Backdoor', 'DoS', 'Exploit', 'Generic', 'Reconnaissance', 'Shellcode', 'Worm']
cm = confusion_matrix(y_eval, y_pred)
plot_confusion_matrix(cm, labels, classes=list(range(9)), normalize=False, title='Confusion matrix')
plot_confusion_matrix(cm, labels, classes=list(range(9)), normalize=True, title='Confusion matrix normalized')
print("Each row adds 1 in total")
# Out:
# Confusion matrix, without normalization
# [[      0       0      19     441      14     337     544       0       0
#         0]
#  [      0       0      38     392      11     322     417       1       0
#         0]
#  [      0       0     200    2826      49    1795    3288       9       3
#         0]
#  [      0       0     336    5213     365    2316   13939      14      24
#         0]
#  [      0       0      49    2448    1126    1053    7396       7      15
#         0]
#  [      0       0      42     596      83   99084    8101       1       7
#         0]
#  [      0       0       3    3849    2261     949 1101541      14     509
#         0]
#  [      0       0      55    1405     546    2577    2404       8       0
#         0]
#  [      0       0       0      14       6       0     697       0      21
#         0]
#  [      0       0       0      12       9       3      66       0       0
#         0]]
# Normalized confusion matrix
# [[0.00000000e+00 0.00000000e+00 1.40221402e-02 3.25461255e-01
#   1.03321033e-02 2.48708487e-01 4.01476015e-01 0.00000000e+00
#   0.00000000e+00 0.00000000e+00]
#  [0.00000000e+00 0.00000000e+00 3.21761219e-02 3.31922100e-01
#   9.31414056e-03 2.72650296e-01 3.53090601e-01 8.46740051e-04
#   0.00000000e+00 0.00000000e+00]
#  [0.00000000e+00 0.00000000e+00 2.44798042e-02 3.45899633e-01
#   5.99755202e-03 2.19706242e-01 4.02447980e-01 1.10159119e-03
#   3.67197062e-04 0.00000000e+00]
#  [0.00000000e+00 0.00000000e+00 1.51303643e-02 2.34745801e-01
#   1.64362588e-02 1.04291440e-01 6.27684964e-01 6.30431846e-04
#   1.08074031e-03 0.00000000e+00]
#  [0.00000000e+00 0.00000000e+00 4.05159583e-03 2.02414420e-01
#   9.31040185e-02 8.70679676e-02 6.11542914e-01 5.78799405e-04
#   1.24028444e-03 0.00000000e+00]
#  [0.00000000e+00 0.00000000e+00 3.89198806e-04 5.52291640e-03
#   7.69130975e-04 9.18175584e-01 7.50690365e-02 9.26663825e-06
#   6.48664677e-05 0.00000000e+00]
#  [0.00000000e+00 0.00000000e+00 2.70483245e-06 3.47030004e-03
#   2.03854206e-03 8.55628666e-04 9.93161282e-01 1.26225515e-05
#   4.58919906e-04 0.00000000e+00]
#  [0.00000000e+00 0.00000000e+00 7.86275911e-03 2.00857756e-01
#   7.80557541e-02 3.68406004e-01 3.43674053e-01 1.14367405e-03
#   0.00000000e+00 0.00000000e+00]
#  [0.00000000e+00 0.00000000e+00 0.00000000e+00 1.89701897e-02
#   8.13008130e-03 0.00000000e+00 9.44444444e-01 0.00000000e+00
#   2.84552846e-02 0.00000000e+00]
#  [0.00000000e+00 0.00000000e+00 0.00000000e+00 1.33333333e-01
#   1.00000000e-01 3.33333333e-02 7.33333333e-01 0.00000000e+00
#   0.00000000e+00 0.00000000e+00]]
# Each row adds 1 in total

# %% [markdown]
# ## **Error parameters**

# %%
print("Printing the parameters of each class...")
print("\n")
# TP
TP = np.diag(cm)

# FP
FP = []
for i in range(cm.shape[0]):
    FP.append(sum(cm[:,i]) - cm[i,i])

# FN    
FN = []
for i in range(cm.shape[0]):
    FN.append(sum(cm[i,:]) - cm[i,i])    

# TN
TN = []
for i in range(cm.shape[0]):
    temp = np.delete(cm, i, 0)   # delete ith row
    temp = np.delete(temp, i, 1)  # delete ith column
    TN.append(sum(sum(temp)))   

# Creating the lists
FPR = []
TNR = []
FNR = []
TPR = []
ACC = []
PRE = []
REC = []
F1 = []
for i in range(cm.shape[0]):
    fpri = FP[i]/(TN[i]+FP[i])*100
    tnri = TN[i]/(TN[i]+FP[i])*100
    fnri = FN[i]/(FN[i]+TP[i])*100
    tpri = TP[i]/(TP[i]+FN[i])*100
    acci = (TP[i]+TN[i])/(TP[i]+FN[i]+TN[i]+FP[i])*100
    prei = TP[i]/(TP[i]+FP[i])*100
    reci = TP[i]/(TP[i]+FN[i])*100
    f1i = 2*(prei*reci)/(prei+reci)

    FPR.append(round(fpri,2))
    TNR.append(round(tnri,2))
    FNR.append(round(fnri,2))
    TPR.append(round(tpri,2))
    ACC.append(round(acci,2))
    PRE.append(round(prei,2))
    REC.append(round(reci,2))
    F1.append(round(f1i,2))

# Making a dataframe for printing a table
TPs=np.asarray(TP)
FPs=np.asarray(FP)
FNs=np.asarray(FN)
TNs=np.asarray(TN)
FPRs=np.asarray(FPR)
TNRs=np.asarray(TNR)
FNRs=np.asarray(FNR)
TPRs=np.asarray(TPR)
ACCs=np.asarray(ACC)
PREs=np.asarray(PRE)
RECs=np.asarray(REC)
F1s=np.asarray(F1)

TPt= TPs.reshape(TPs.shape[0], 1)
FPt= FPs.reshape(FPs.shape[0], 1)
FNt= FNs.reshape(FNs.shape[0], 1)
TNt= TNs.reshape(TNs.shape[0], 1)
FPRt= FPRs.reshape(FPRs.shape[0], 1)
TNRt= TNRs.reshape(TNRs.shape[0], 1)
FNRt= FNRs.reshape(FNRs.shape[0], 1)
TPRt= TPRs.reshape(TPRs.shape[0], 1)
ACCt= ACCs.reshape(ACCs.shape[0], 1)
PREt= PREs.reshape(PREs.shape[0], 1)
RECt= RECs.reshape(RECs.shape[0], 1)
F1t= F1s.reshape(F1s.shape[0], 1)

param = np.concatenate((TPt, FPt, FNt, TNt, FPRt, TNRt, FNRt, TPRt, ACCt, PREt, RECt, F1t), axis=1)

dfParam= pd.DataFrame(param, columns = ['TP', 'FP', 'FN', 'TN', 'FPR/FAR(%)', 'TNR(%)', 'FNR(%)', 'TPR/DR(%)', 'Accuracy(%)', 'Precision(%)', 'Recall(%)', 'F1 Score(%)'], index=labels)

dfParam[0:len(labels)]
# Out:
# Printing the parameters of each class...
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:38: RuntimeWarning: invalid value encountered in long_scalars
#                        TP       FP  ...  Recall(%)  F1 Score(%)
# Normal                0.0      0.0  ...       0.00          NaN
# Fuzzers               0.0      0.0  ...       0.00          NaN
# Analysis            200.0    542.0  ...       2.45         4.49
# Backdoor           5213.0  11983.0  ...      23.47        26.46
# DoS                1126.0   3344.0  ...       9.31        13.60
# Exploit           99084.0   9352.0  ...      91.82        91.60
# Generic         1101541.0  36852.0  ...      99.32        98.02
# Reconnaissance        8.0     46.0  ...       0.11         0.23
# Shellcode            21.0    558.0  ...       2.85         3.19
# Worm                  0.0      0.0  ...       0.00          NaN
#
# [10 rows x 12 columns]

# %% [markdown]
# ## **ROC**

# %%
# ROC
def plot_roc_curve(Y_test, Y_pred, classes, labels):
    from sklearn import metrics
    import matplotlib.pyplot as plt
    fpr = dict()
    tpr = dict()
    roc_auc = dict()
    for i in range(classes):
        fpr[i], tpr[i], _ = metrics.roc_curve(Y_test[:, i], Y_pred[:, i])
        roc_auc[i] = metrics.auc(fpr[i], tpr[i])   
    # Compute micro-average ROC curve and ROC area
    fpr["micro"], tpr["micro"], _ = metrics.roc_curve(Y_test.ravel(), Y_pred.ravel())
    roc_auc["micro"] = metrics.auc(fpr["micro"], tpr["micro"])   
    #plt.figure()
    lw = 2
    plt.rcParams["figure.figsize"] = [6,4]
    for i in range(classes):
      plt.plot(fpr[i], tpr[i], color='darkorange',
              lw=lw, label='ROC curve (area = %0.4f)' % roc_auc[i])
      plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')
      plt.xlim([0.0, 1.0])
      plt.ylim([0.0, 1.05])
      plt.xlabel('False Positive Rate')
      plt.ylabel('True Positive Rate')
      plt.title('Receiver operating characteristic (class '+ str(i+1) +', '+ labels[i] +')')
      plt.legend(loc="lower right")
      plt.show()

plot_roc_curve(y_test, y_p, len(labels), labels)
