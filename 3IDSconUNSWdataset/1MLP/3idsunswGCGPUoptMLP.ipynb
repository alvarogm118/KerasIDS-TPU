# %% [markdown]
# ### **Data preprocessing**

# %%
# Google Drive
from google.colab import drive
drive.mount('/content/drive')

import numpy as np
import pandas as pd
from sklearn import metrics
from scipy.stats import zscore
import os
from tensorflow.keras.utils import get_file
from sklearn.preprocessing import normalize # , LabelEncoder

# Read the info about features
try:
    path = get_file('NUSW-NB15_features.csv', origin='https://www.unsw.adfa.edu.au/unsw-canberra-cyber/cybersecurity/ADFA-NB15-Datasets/NUSW-NB15_features.csv')
except:
    print('Error downloading')
    raise

# Read the info about features
print('Reading feature info...')
data_info = pd.read_csv(path, encoding = "ISO-8859-1", header=None).values
features = data_info[1:-2,:]
feature_names = features[:, 1]  # Names of the features in a list
feature_types = np.array([item.lower() for item in features[:, 2]])  # The types of the corresponding features in 'features_names'
                         
# index arrays for different types of features
print('Finding column indices for feature types...')
nominal_cols = np.where(feature_types == "nominal")[0]
integer_cols = np.where(feature_types == "integer")[0]
binary_cols = np.where(feature_types == "binary")[0]
float_cols = np.where(feature_types == "float")[0]

# arrays for names of the different types of features
nominal_names = feature_names[nominal_cols]
integer_names = feature_names[integer_cols]
binary_names = feature_names[binary_cols]
float_names = feature_names[float_cols]

print('Reading csv file...')
#dataframe = pandas.read_csv("UNSW.csv", header=None)
df = pd.read_csv("/content/drive/My Drive/UNSW.csv", header=None)

print('Preprocessing...')
print('Converting data...')
df[integer_cols] = df[integer_cols].apply(pd.to_numeric, errors='coerce')
df[binary_cols] = df[binary_cols].apply(pd.to_numeric, errors='coerce')
df[float_cols] = df[float_cols].apply(pd.to_numeric, errors='coerce')
df[48] = df[48].apply(pd.to_numeric, errors='coerce')
#dataframe[nominal_cols] = dataframe[nominal_cols].astype(str)

print('Replacing NaNs...')
df.loc[:,47] = df.loc[:,47].replace(np.nan,'normal', regex=True).apply(lambda x: x.strip().lower())
df.loc[:,binary_cols] = df.loc[:,binary_cols].replace(np.nan, 0, regex=True)
df.loc[:,37:39] = df.loc[:,37:39].replace(np.nan, 0, regex=True)
# dataframe.loc[:,float_cols] = dataframe.loc[:,float_cols].replace(np.nan, 0, regex=True)

print('Stripping nominal columns and setting them lower case...')
df.loc[:,nominal_cols] = df.loc[:,nominal_cols].applymap(lambda x: x.strip().lower())

print('Changing targets \'backdoors\' to \'backdoor\'...')
df.loc[:,47] = df.loc[:,47].replace('backdoors','backdoor', regex=True).apply(lambda x: x.strip().lower())

print('Adding column headers...')
col = [
    'Srcip',
    'Sport',
    'Dstip',
    'Dsport',
    'Proto',
    'State',
    'Dur',
    'sbytes',
    'dbytes',
    'Sttl',
    'Dttl',
    'Sloss',
    'dloss',
    'service',
    'sload',
    'dload',
    'spkts',
    'dpkts',
    'Swin',
    'Dwin',
    'Stcpb',
    'Dtcpb',
    'Smeansz',
    'Dmeansz',
    'trans_depth',
    'res_bdy_len',
    'Sjit',
    'Djit',
    'Stime',
    'Ltime',
    'Sintpkt',
    'Dintpkt',
    'Tcprtt',
    'Synack',
    'Ackdat',
    'is_sm_ips_ports',
    'ct_state_ttl',
    'ct_flw_http_mthd',
    'is_ftp_login',
    'ct_ftp_cmd',
    'ct_srv_src',
    'ct_srv_dst',
    'ct_dst_ltm',
    'ct_src_ltm',
    'ct_src_dport_ltm',
    'ct_dst_sport_ltm',
    'ct_dst_src_ltm',
    'attack_cat',
    'Label'
]
df.columns = col

print('Copying values...')
dataset = df.values

# display 5 rows
print('Printing 5 rows of the processed dataframe...')
df[0:5]
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Reading feature info...
# Finding column indices for feature types...
# Reading csv file...
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (1,3,39,47) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# Preprocessing...
# Converting data...
# Replacing NaNs...
# Stripping nominal columns and setting them lower case...
# Changing targets 'backdoors' to 'backdoor'...
# Adding column headers...
# Copying values...
# Printing 5 rows of the processed dataframe...
#         Srcip    Sport          Dstip  ...  ct_dst_src_ltm attack_cat Label
# 0  59.166.0.0   1390.0  149.171.126.6  ...               1     normal     0
# 1  59.166.0.0  33661.0  149.171.126.9  ...               2     normal     0
# 2  59.166.0.6   1464.0  149.171.126.7  ...               1     normal     0
# 3  59.166.0.5   3593.0  149.171.126.5  ...               1     normal     0
# 4  59.166.0.3  49664.0  149.171.126.0  ...               1     normal     0
#
# [5 rows x 49 columns]

# %% [markdown]
# ## **Transforming into numeric**

# %%
# Subsets of the dataset which have data that is only of the corresponding data type (nominal, integer etc)
# Columns don't include the target classes (the two last columns of the dataset)
print('Slicing dataset...')
nominal_x = dataset[:, nominal_cols][:,:]
integer_x = dataset[:, integer_cols][:,:].astype(np.float32)    
binary_x = dataset[:, binary_cols][:,:].astype(np.float32)
float_x = dataset[:, float_cols][:,:].astype(np.float32)

# Make nominal (textual) data binary vectors
print('Vectorizing nominal data...')
from sklearn.feature_extraction import DictVectorizer
v = DictVectorizer(sparse=False)
# D = [{'foo': 1, 'bar': 2}, {'foo': 3, 'baz': 1}]
D = map(lambda dataline: dict(zip(nominal_names, dataline)), nominal_x)
labeled_nominal_x = v.fit_transform(D).astype(np.float32)
del nominal_x

print('Concatenating X...')
X = np.concatenate((integer_x, labeled_nominal_x, float_x, binary_x), axis=1)

del integer_x
del labeled_nominal_x
del float_x
del binary_x

# Find rows that have NaNs
print('Removing NaNs if any...')
nan_indices = []
for feature_i in range(X.shape[1]):
    nan_indices.extend(list(np.where(np.isnan(X[:, feature_i]))[0]))
nan_indices = np.unique(nan_indices)

# Remove rows that have NaNs
X_no_nans = np.delete(X, nan_indices, axis=0)

del X

print('Normalizing X...')
normalized_X = normalize(X_no_nans, copy=False)

del X_no_nans


data_dim = normalized_X.shape
print('Data dimensions are', data_dim)

print('Creating target Y matrix...')
Y = np.delete(dataset[:, -2], nan_indices)
Y_A = np.delete(dataset[:, -1], nan_indices).astype(np.int16) # Is attack or not

del dataset

print('Vectorizing Y labels...')
D = [{'attack_cat': y} for y in Y]
labeled_Y = v.fit_transform(D)

del D

print('Done')
# Out:
# Slicing dataset...
# Vectorizing nominal data...
# Concatenating X...
# Removing NaNs if any...
# Normalizing X...
# Data dimensions are (2539739, 294)
# Creating target Y matrix...
# Vectorizing Y labels...
# Done

# %% [markdown]
# ## **Train the Neural Network**

# %%
import pandas as pd
import io
import requests
import numpy as np
import os
import timeit
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation, Dropout
from tensorflow.keras.callbacks import EarlyStopping
from keras import backend as K

#Custom Metrics
def recall_m(y_true, y_pred):
        true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
        possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
        recall = true_positives / (possible_positives + K.epsilon())
        return recall

def precision_m(y_true, y_pred):
        true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
        predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
        precision = true_positives / (predicted_positives + K.epsilon())
        return precision

def f1_m(y_true, y_pred):
    precision = precision_m(y_true, y_pred)
    recall = recall_m(y_true, y_pred)
    return 2*((precision*recall)/(precision+recall+K.epsilon()))

# Create a test/train split. 50% test
# Split into train/test
x_train, x_test, y_train, y_test = train_test_split(
    normalized_X, labeled_Y, test_size=0.5, random_state=42)

num_of_features = x_train.shape[1] #294 features
nb_classes = y_train.shape[1] #10 detected actions

#Model
model = Sequential()

model.add(Dense(50, input_dim=num_of_features, kernel_initializer='normal', activation='relu'))
model.add(Dense(nb_classes, kernel_initializer='normal'))
model.add(Dense(nb_classes,activation='softmax'))

model.compile(optimizer='adam',loss='categorical_crossentropy', metrics=['accuracy', precision_m, recall_m, f1_m])

monitor = EarlyStopping(monitor='val_loss', min_delta=1e-5, patience=120, verbose=1, mode='auto')

startTime = timeit.default_timer()
history = model.fit(x_train,y_train,validation_data=(x_test,y_test),callbacks=[monitor],verbose=1,epochs=128,batch_size=256)
elapsedTime = timeit.default_timer() - startTime

print("Time taken for the Network to train:",elapsedTime)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/keras/initializers.py:143: calling RandomNormal.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# Train on 1269869 samples, validate on 1269870 samples
# Epoch 1/128
# 1269869/1269869 [==============================] - 32s 25us/sample - loss: 0.3706 - acc: 0.8721 - precision_m: 0.9420 - recall_m: 0.7908 - f1_m: 0.8580 - val_loss: 0.3446 - val_acc: 0.8739 - val_precision_m: 0.8752 - val_recall_m: 0.8734 - val_f1_m: 0.8743
# Epoch 2/128
# 1269869/1269869 [==============================] - 31s 24us/sample - loss: 0.3429 - acc: 0.8727 - precision_m: 0.9585 - recall_m: 0.7962 - f1_m: 0.8685 - val_loss: 0.3420 - val_acc: 0.8742 - val_precision_m: 0.9713 - val_recall_m: 0.7838 - val_f1_m: 0.8673
# Epoch 3/128
# 1269869/1269869 [==============================] - 31s 24us/sample - loss: 0.3418 - acc: 0.8726 - precision_m: 0.9565 - recall_m: 0.7978 - f1_m: 0.8686 - val_loss: 0.3405 - val_acc: 0.8742 - val_precision_m: 0.9712 - val_recall_m: 0.7840 - val_f1_m: 0.8674
# Epoch 4/128
# 1269869/1269869 [==============================] - 31s 24us/sample - loss: 0.3403 - acc: 0.8726 - precision_m: 0.9559 - recall_m: 0.7983 - f1_m: 0.8686 - val_loss: 0.3394 - val_acc: 0.8743 - val_precision_m: 0.9713 - val_recall_m: 0.7839 - val_f1_m: 0.8674
# Epoch 5/128
# 1269869/1269869 [==============================] - 31s 24us/sample - loss: 0.3385 - acc: 0.8729 - precision_m: 0.9558 - recall_m: 0.7983 - f1_m: 0.8685 - val_loss: 0.3373 - val_acc: 0.8743 - val_precision_m: 0.9714 - val_recall_m: 0.7839 - val_f1_m: 0.8674
# Epoch 6/128
# 1269869/1269869 [==============================] - 31s 24us/sample - loss: 0.3365 - acc: 0.8727 - precision_m: 0.9521 - recall_m: 0.8022 - f1_m: 0.8690 - val_loss: 0.3348 - val_acc: 0.8744 - val_precision_m: 0.9713 - val_recall_m: 0.7840 - val_f1_m: 0.8675
# Epoch 7/128
# 1269869/1269869 [==============================] - 31s 25us/sample - loss: 0.3344 - acc: 0.8730 - precision_m: 0.9504 - recall_m: 0.8036 - f1_m: 0.8691 - val_loss: 0.3325 - val_acc: 0.8744 - val_precision_m: 0.9713 - val_recall_m: 0.7840 - val_f1_m: 0.8675
# Epoch 8/128
# 1269869/1269869 [==============================] - 31s 24us/sample - loss: 0.3320 - acc: 0.8725 - precision_m: 0.9473 - recall_m: 0.8064 - f1_m: 0.8692 - val_loss: 0.3346 - val_acc: 0.8744 - val_precision_m: 0.8753 - val_recall_m: 0.8735 - val_f1_m: 0.8744
# Epoch 9/128
# 1269869/1269869 [==============================] - 31s 24us/sample - loss: 0.3294 - acc: 0.8722 - precision_m: 0.9459 - recall_m: 0.8080 - f1_m: 0.8695 - val_loss: 0.3276 - val_acc: 0.8744 - val_precision_m: 0.9713 - val_recall_m: 0.7840 - val_f1_m: 0.8675
# Epoch 10/128
# 1269869/1269869 [==============================] - 31s 24us/sample - loss: 0.3272 - acc: 0.8727 - precision_m: 0.9412 - recall_m: 0.8119 - f1_m: 0.8696 - val_loss: 0.3247 - val_acc: 0.8744 - val_precision_m: 0.9713 - val_recall_m: 0.7841 - val_f1_m: 0.8675
# Epoch 11/128
# 1269869/1269869 [==============================] - 32s 25us/sample - loss: 0.3253 - acc: 0.8730 - precision_m: 0.9428 - recall_m: 0.8109 - f1_m: 0.8698 - val_loss: 0.3228 - val_acc: 0.8744 - val_precision_m: 0.9713 - val_recall_m: 0.7841 - val_f1_m: 0.8675
# Epoch 12/128
# 1269869/1269869 [==============================] - 31s 24us/sample - loss: 0.3240 - acc: 0.8729 - precision_m: 0.9376 - recall_m: 0.8153 - f1_m: 0.8699 - val_loss: 0.3217 - val_acc: 0.8779 - val_precision_m: 0.9713 - val_recall_m: 0.7841 - val_f1_m: 0.8675
# Epoch 13/128
# 1269869/1269869 [==============================] - 31s 24us/sample - loss: 0.3233 - acc: 0.8735 - precision_m: 0.9343 - recall_m: 0.8187 - f1_m: 0.8704 - val_loss: 0.3233 - val_acc: 0.8684 - val_precision_m: 0.9315 - val_recall_m: 0.8190 - val_f1_m: 0.8715
# Epoch 14/128
# 1269869/1269869 [==============================] - 31s 24us/sample - loss: 0.3217 - acc: 0.8752 - precision_m: 0.9358 - recall_m: 0.8198 - f1_m: 0.8718 - val_loss: 0.3250 - val_acc: 0.8744 - val_precision_m: 0.8756 - val_recall_m: 0.8735 - val_f1_m: 0.8746
# Epoch 15/128
# 1269869/1269869 [==============================] - 31s 24us/sample - loss: 0.3199 - acc: 0.8781 - precision_m: 0.9356 - recall_m: 0.8230 - f1_m: 0.8739 - val_loss: 0.3256 - val_acc: 0.8746 - val_precision_m: 0.8771 - val_recall_m: 0.8713 - val_f1_m: 0.8742
# Epoch 16/128
# 1269869/1269869 [==============================] - 31s 24us/sample - loss: 0.3177 - acc: 0.8821 - precision_m: 0.9331 - recall_m: 0.8315 - f1_m: 0.8781 - val_loss: 0.3147 - val_acc: 0.8921 - val_precision_m: 0.9703 - val_recall_m: 0.8047 - val_f1_m: 0.8796
# Epoch 17/128
# 1269869/1269869 [==============================] - 31s 25us/sample - loss: 0.3153 - acc: 0.8851 - precision_m: 0.9288 - recall_m: 0.8427 - f1_m: 0.8826 - val_loss: 0.3174 - val_acc: 0.8680 - val_precision_m: 0.9383 - val_recall_m: 0.8169 - val_f1_m: 0.8733
# Epoch 18/128
# 1269869/1269869 [==============================] - 31s 24us/sample - loss: 0.3125 - acc: 0.8867 - precision_m: 0.9239 - recall_m: 0.8506 - f1_m: 0.8849 - val_loss: 0.3177 - val_acc: 0.8683 - val_precision_m: 0.9224 - val_recall_m: 0.8204 - val_f1_m: 0.8683
# Epoch 19/128
# 1269869/1269869 [==============================] - 31s 24us/sample - loss: 0.3102 - acc: 0.8864 - precision_m: 0.9171 - recall_m: 0.8568 - f1_m: 0.8853 - val_loss: 0.3078 - val_acc: 0.8754 - val_precision_m: 0.9450 - val_recall_m: 0.8183 - val_f1_m: 0.8770
# Epoch 20/128
# 1269869/1269869 [==============================] - 31s 24us/sample - loss: 0.3081 - acc: 0.8858 - precision_m: 0.9123 - recall_m: 0.8601 - f1_m: 0.8849 - val_loss: 0.3052 - val_acc: 0.8920 - val_precision_m: 0.9070 - val_recall_m: 0.8731 - val_f1_m: 0.8897
# Epoch 21/128
# 1269869/1269869 [==============================] - 32s 25us/sample - loss: 0.3067 - acc: 0.8860 - precision_m: 0.9096 - recall_m: 0.8624 - f1_m: 0.8849 - val_loss: 0.3046 - val_acc: 0.8805 - val_precision_m: 0.8908 - val_recall_m: 0.8656 - val_f1_m: 0.8780
# Epoch 22/128
# 1269869/1269869 [==============================] - 31s 24us/sample - loss: 0.3058 - acc: 0.8857 - precision_m: 0.9073 - recall_m: 0.8637 - f1_m: 0.8845 - val_loss: 0.3035 - val_acc: 0.8842 - val_precision_m: 0.8927 - val_recall_m: 0.8664 - val_f1_m: 0.8793
# Epoch 23/128
# 1269869/1269869 [==============================] - 31s 24us/sample - loss: 0.3052 - acc: 0.8858 - precision_m: 0.9070 - recall_m: 0.8642 - f1_m: 0.8846 - val_loss: 0.3094 - val_acc: 0.8755 - val_precision_m: 0.8836 - val_recall_m: 0.8665 - val_f1_m: 0.8750
# Epoch 24/128
# 1269869/1269869 [==============================] - 31s 24us/sample - loss: 0.3046 - acc: 0.8856 - precision_m: 0.9063 - recall_m: 0.8648 - f1_m: 0.8846 - val_loss: 0.3029 - val_acc: 0.8808 - val_precision_m: 0.8931 - val_recall_m: 0.8632 - val_f1_m: 0.8779
# Epoch 25/128
# 1269869/1269869 [==============================] - 31s 24us/sample - loss: 0.3039 - acc: 0.8857 - precision_m: 0.9054 - recall_m: 0.8655 - f1_m: 0.8846 - val_loss: 0.3027 - val_acc: 0.8805 - val_precision_m: 0.8912 - val_recall_m: 0.8636 - val_f1_m: 0.8771
# Epoch 26/128
# 1269869/1269869 [==============================] - 31s 24us/sample - loss: 0.3035 - acc: 0.8856 - precision_m: 0.9055 - recall_m: 0.8654 - f1_m: 0.8846 - val_loss: 0.3026 - val_acc: 0.8863 - val_precision_m: 0.8985 - val_recall_m: 0.8766 - val_f1_m: 0.8874
# Epoch 27/128
# 1269869/1269869 [==============================] - 31s 25us/sample - loss: 0.3027 - acc: 0.8856 - precision_m: 0.9047 - recall_m: 0.8659 - f1_m: 0.8845 - val_loss: 0.3016 - val_acc: 0.8843 - val_precision_m: 0.8910 - val_recall_m: 0.8707 - val_f1_m: 0.8807
# Epoch 28/128
# 1269869/1269869 [==============================] - 31s 24us/sample - loss: 0.3022 - acc: 0.8857 - precision_m: 0.9051 - recall_m: 0.8658 - f1_m: 0.8846 - val_loss: 0.3005 - val_acc: 0.8843 - val_precision_m: 0.8932 - val_recall_m: 0.8652 - val_f1_m: 0.8790
# Epoch 29/128
# 1269869/1269869 [==============================] - 31s 24us/sample - loss: 0.3018 - acc: 0.8859 - precision_m: 0.9046 - recall_m: 0.8660 - f1_m: 0.8845 - val_loss: 0.2999 - val_acc: 0.8860 - val_precision_m: 0.8914 - val_recall_m: 0.8768 - val_f1_m: 0.8840
# Epoch 30/128
# 1269869/1269869 [==============================] - 31s 24us/sample - loss: 0.3012 - acc: 0.8857 - precision_m: 0.9046 - recall_m: 0.8660 - f1_m: 0.8845 - val_loss: 0.2987 - val_acc: 0.8882 - val_precision_m: 0.8995 - val_recall_m: 0.8714 - val_f1_m: 0.8852
# Epoch 31/128
# 1269869/1269869 [==============================] - 31s 25us/sample - loss: 0.3008 - acc: 0.8856 - precision_m: 0.9051 - recall_m: 0.8657 - f1_m: 0.8846 - val_loss: 0.3077 - val_acc: 0.8686 - val_precision_m: 0.9323 - val_recall_m: 0.8189 - val_f1_m: 0.8718
# Epoch 32/128
# 1269869/1269869 [==============================] - 31s 24us/sample - loss: 0.3003 - acc: 0.8858 - precision_m: 0.9042 - recall_m: 0.8664 - f1_m: 0.8845 - val_loss: 0.3002 - val_acc: 0.8922 - val_precision_m: 0.9024 - val_recall_m: 0.8788 - val_f1_m: 0.8904
# Epoch 33/128
# 1269869/1269869 [==============================] - 31s 24us/sample - loss: 0.3001 - acc: 0.8858 - precision_m: 0.9047 - recall_m: 0.8660 - f1_m: 0.8845 - val_loss: 0.3004 - val_acc: 0.8968 - val_precision_m: 0.9071 - val_recall_m: 0.8784 - val_f1_m: 0.8925
# Epoch 34/128
# 1269869/1269869 [==============================] - 31s 24us/sample - loss: 0.2997 - acc: 0.8859 - precision_m: 0.9046 - recall_m: 0.8664 - f1_m: 0.8847 - val_loss: 0.2978 - val_acc: 0.8864 - val_precision_m: 0.8989 - val_recall_m: 0.8760 - val_f1_m: 0.8873
# Epoch 35/128
# 1269869/1269869 [==============================] - 31s 24us/sample - loss: 0.2992 - acc: 0.8859 - precision_m: 0.9046 - recall_m: 0.8663 - f1_m: 0.8847 - val_loss: 0.2976 - val_acc: 0.8922 - val_precision_m: 0.9029 - val_recall_m: 0.8784 - val_f1_m: 0.8905
# Epoch 36/128
# 1269869/1269869 [==============================] - 31s 24us/sample - loss: 0.2989 - acc: 0.8860 - precision_m: 0.9051 - recall_m: 0.8665 - f1_m: 0.8850 - val_loss: 0.2986 - val_acc: 0.8923 - val_precision_m: 0.9077 - val_recall_m: 0.8778 - val_f1_m: 0.8925
# Epoch 37/128
# 1269869/1269869 [==============================] - 31s 24us/sample - loss: 0.2985 - acc: 0.8859 - precision_m: 0.9050 - recall_m: 0.8662 - f1_m: 0.8848 - val_loss: 0.2997 - val_acc: 0.8969 - val_precision_m: 0.9095 - val_recall_m: 0.8766 - val_f1_m: 0.8927
# Epoch 38/128
# 1269869/1269869 [==============================] - 31s 24us/sample - loss: 0.2983 - acc: 0.8860 - precision_m: 0.9048 - recall_m: 0.8661 - f1_m: 0.8846 - val_loss: 0.2966 - val_acc: 0.8845 - val_precision_m: 0.8932 - val_recall_m: 0.8653 - val_f1_m: 0.8790
# Epoch 39/128
# 1269869/1269869 [==============================] - 31s 24us/sample - loss: 0.2978 - acc: 0.8859 - precision_m: 0.9042 - recall_m: 0.8665 - f1_m: 0.8846 - val_loss: 0.2985 - val_acc: 0.8804 - val_precision_m: 0.9467 - val_recall_m: 0.8165 - val_f1_m: 0.8767
# Epoch 40/128
# 1269869/1269869 [==============================] - 31s 24us/sample - loss: 0.2977 - acc: 0.8860 - precision_m: 0.9054 - recall_m: 0.8659 - f1_m: 0.8848 - val_loss: 0.2966 - val_acc: 0.8863 - val_precision_m: 0.9001 - val_recall_m: 0.8700 - val_f1_m: 0.8848
# Epoch 41/128
# 1269869/1269869 [==============================] - 31s 25us/sample - loss: 0.2973 - acc: 0.8860 - precision_m: 0.9042 - recall_m: 0.8668 - f1_m: 0.8847 - val_loss: 0.2998 - val_acc: 0.8969 - val_precision_m: 0.8990 - val_recall_m: 0.8897 - val_f1_m: 0.8943
# Epoch 42/128
# 1269869/1269869 [==============================] - 31s 24us/sample - loss: 0.2972 - acc: 0.8859 - precision_m: 0.9049 - recall_m: 0.8663 - f1_m: 0.8848 - val_loss: 0.2973 - val_acc: 0.8757 - val_precision_m: 0.9411 - val_recall_m: 0.8206 - val_f1_m: 0.8766
# Epoch 43/128
# 1269869/1269869 [==============================] - 31s 24us/sample - loss: 0.2970 - acc: 0.8861 - precision_m: 0.9039 - recall_m: 0.8670 - f1_m: 0.8846 - val_loss: 0.2957 - val_acc: 0.8861 - val_precision_m: 0.9002 - val_recall_m: 0.8740 - val_f1_m: 0.8869
# Epoch 44/128
# 1269869/1269869 [==============================] - 31s 24us/sample - loss: 0.2967 - acc: 0.8861 - precision_m: 0.9041 - recall_m: 0.8671 - f1_m: 0.8847 - val_loss: 0.2956 - val_acc: 0.8883 - val_precision_m: 0.8987 - val_recall_m: 0.8750 - val_f1_m: 0.8867
# Epoch 45/128
# 1269869/1269869 [==============================] - 31s 24us/sample - loss: 0.2965 - acc: 0.8860 - precision_m: 0.9038 - recall_m: 0.8672 - f1_m: 0.8847 - val_loss: 0.2993 - val_acc: 0.8698 - val_precision_m: 0.9318 - val_recall_m: 0.8198 - val_f1_m: 0.8721
# Epoch 46/128
# 1269869/1269869 [==============================] - 31s 24us/sample - loss: 0.2963 - acc: 0.8861 - precision_m: 0.9042 - recall_m: 0.8670 - f1_m: 0.8848 - val_loss: 0.2953 - val_acc: 0.8807 - val_precision_m: 0.9110 - val_recall_m: 0.8618 - val_f1_m: 0.8857
# Epoch 47/128
# 1269869/1269869 [==============================] - 31s 24us/sample - loss: 0.2961 - acc: 0.8861 - precision_m: 0.9046 - recall_m: 0.8669 - f1_m: 0.8849 - val_loss: 0.3016 - val_acc: 0.8995 - val_precision_m: 0.9045 - val_recall_m: 0.8923 - val_f1_m: 0.8984
# Epoch 48/128
# 1269869/1269869 [==============================] - 31s 24us/sample - loss: 0.2959 - acc: 0.8861 - precision_m: 0.9039 - recall_m: 0.8673 - f1_m: 0.8848 - val_loss: 0.2978 - val_acc: 0.8699 - val_precision_m: 0.9377 - val_recall_m: 0.8197 - val_f1_m: 0.8746
# Epoch 49/128
# 1269869/1269869 [==============================] - 31s 24us/sample - loss: 0.2958 - acc: 0.8862 - precision_m: 0.9053 - recall_m: 0.8662 - f1_m: 0.8848 - val_loss: 0.2951 - val_acc: 0.8885 - val_precision_m: 0.8977 - val_recall_m: 0.8766 - val_f1_m: 0.8870
# Epoch 50/128
# 1269869/1269869 [==============================] - 31s 24us/sample - loss: 0.2955 - acc: 0.8862 - precision_m: 0.9034 - recall_m: 0.8679 - f1_m: 0.8849 - val_loss: 0.2969 - val_acc: 0.8970 - val_precision_m: 0.9039 - val_recall_m: 0.8900 - val_f1_m: 0.8969
# Epoch 51/128
# 1269869/1269869 [==============================] - 31s 24us/sample - loss: 0.2953 - acc: 0.8863 - precision_m: 0.9045 - recall_m: 0.8671 - f1_m: 0.8849 - val_loss: 0.2965 - val_acc: 0.8758 - val_precision_m: 0.9054 - val_recall_m: 0.8655 - val_f1_m: 0.8849
# Epoch 52/128
# 1269869/1269869 [==============================] - 31s 24us/sample - loss: 0.2952 - acc: 0.8862 - precision_m: 0.9043 - recall_m: 0.8673 - f1_m: 0.8849 - val_loss: 0.2951 - val_acc: 0.8965 - val_precision_m: 0.9039 - val_recall_m: 0.8796 - val_f1_m: 0.8916
# Epoch 53/128
# 1269869/1269869 [==============================] - 30s 24us/sample - loss: 0.2953 - acc: 0.8863 - precision_m: 0.9053 - recall_m: 0.8666 - f1_m: 0.8850 - val_loss: 0.2944 - val_acc: 0.8845 - val_precision_m: 0.9448 - val_recall_m: 0.8194 - val_f1_m: 0.8775
# Epoch 54/128
# 1269869/1269869 [==============================] - 30s 24us/sample - loss: 0.2949 - acc: 0.8861 - precision_m: 0.9040 - recall_m: 0.8677 - f1_m: 0.8850 - val_loss: 0.2960 - val_acc: 0.8723 - val_precision_m: 0.9372 - val_recall_m: 0.8205 - val_f1_m: 0.8749
# Epoch 55/128
# 1269869/1269869 [==============================] - 30s 24us/sample - loss: 0.2946 - acc: 0.8864 - precision_m: 0.9042 - recall_m: 0.8680 - f1_m: 0.8853 - val_loss: 0.2937 - val_acc: 0.8862 - val_precision_m: 0.8916 - val_recall_m: 0.8716 - val_f1_m: 0.8815
# Epoch 56/128
# 1269869/1269869 [==============================] - 31s 24us/sample - loss: 0.2945 - acc: 0.8864 - precision_m: 0.9043 - recall_m: 0.8676 - f1_m: 0.8851 - val_loss: 0.2939 - val_acc: 0.8885 - val_precision_m: 0.8992 - val_recall_m: 0.8778 - val_f1_m: 0.8883
# Epoch 57/128
# 1269869/1269869 [==============================] - 31s 24us/sample - loss: 0.2943 - acc: 0.8863 - precision_m: 0.9039 - recall_m: 0.8681 - f1_m: 0.8852 - val_loss: 0.2954 - val_acc: 0.8861 - val_precision_m: 0.8994 - val_recall_m: 0.8751 - val_f1_m: 0.8871
# Epoch 58/128
# 1269869/1269869 [==============================] - 31s 24us/sample - loss: 0.2942 - acc: 0.8864 - precision_m: 0.9040 - recall_m: 0.8681 - f1_m: 0.8852 - val_loss: 0.2934 - val_acc: 0.8923 - val_precision_m: 0.9030 - val_recall_m: 0.8808 - val_f1_m: 0.8918
# Epoch 59/128
# 1269869/1269869 [==============================] - 32s 25us/sample - loss: 0.2941 - acc: 0.8864 - precision_m: 0.9053 - recall_m: 0.8676 - f1_m: 0.8855 - val_loss: 0.2928 - val_acc: 0.8865 - val_precision_m: 0.8911 - val_recall_m: 0.8783 - val_f1_m: 0.8846
# Epoch 60/128
# 1269869/1269869 [==============================] - 31s 24us/sample - loss: 0.2937 - acc: 0.8864 - precision_m: 0.9045 - recall_m: 0.8685 - f1_m: 0.8856 - val_loss: 0.2921 - val_acc: 0.8846 - val_precision_m: 0.8898 - val_recall_m: 0.8716 - val_f1_m: 0.8806
# Epoch 61/128
# 1269869/1269869 [==============================] - 31s 24us/sample - loss: 0.2937 - acc: 0.8866 - precision_m: 0.9043 - recall_m: 0.8683 - f1_m: 0.8854 - val_loss: 0.2925 - val_acc: 0.8811 - val_precision_m: 0.9154 - val_recall_m: 0.8657 - val_f1_m: 0.8898
# Epoch 62/128
# 1269869/1269869 [==============================] - 31s 25us/sample - loss: 0.2936 - acc: 0.8866 - precision_m: 0.9051 - recall_m: 0.8676 - f1_m: 0.8854 - val_loss: 0.2920 - val_acc: 0.8887 - val_precision_m: 0.8983 - val_recall_m: 0.8793 - val_f1_m: 0.8887
# Epoch 63/128
# 1269869/1269869 [==============================] - 31s 24us/sample - loss: 0.2932 - acc: 0.8866 - precision_m: 0.9050 - recall_m: 0.8680 - f1_m: 0.8856 - val_loss: 0.2924 - val_acc: 0.8864 - val_precision_m: 0.8912 - val_recall_m: 0.8810 - val_f1_m: 0.8861
# Epoch 64/128
# 1269869/1269869 [==============================] - 31s 24us/sample - loss: 0.2930 - acc: 0.8866 - precision_m: 0.9055 - recall_m: 0.8682 - f1_m: 0.8859 - val_loss: 0.2942 - val_acc: 0.8846 - val_precision_m: 0.9437 - val_recall_m: 0.8205 - val_f1_m: 0.8777
# Epoch 65/128
# 1269869/1269869 [==============================] - 31s 24us/sample - loss: 0.2927 - acc: 0.8868 - precision_m: 0.9054 - recall_m: 0.8681 - f1_m: 0.8858 - val_loss: 0.2922 - val_acc: 0.8886 - val_precision_m: 0.8975 - val_recall_m: 0.8772 - val_f1_m: 0.8872
# Epoch 66/128
# 1269869/1269869 [==============================] - 32s 25us/sample - loss: 0.2927 - acc: 0.8868 - precision_m: 0.9051 - recall_m: 0.8684 - f1_m: 0.8859 - val_loss: 0.2939 - val_acc: 0.8971 - val_precision_m: 0.9038 - val_recall_m: 0.8920 - val_f1_m: 0.8978
# Epoch 67/128
# 1269869/1269869 [==============================] - 31s 25us/sample - loss: 0.2926 - acc: 0.8868 - precision_m: 0.9059 - recall_m: 0.8678 - f1_m: 0.8859 - val_loss: 0.2908 - val_acc: 0.8887 - val_precision_m: 0.8990 - val_recall_m: 0.8785 - val_f1_m: 0.8886
# Epoch 68/128
# 1269869/1269869 [==============================] - 31s 24us/sample - loss: 0.2924 - acc: 0.8867 - precision_m: 0.9059 - recall_m: 0.8677 - f1_m: 0.8859 - val_loss: 0.2956 - val_acc: 0.8875 - val_precision_m: 0.9012 - val_recall_m: 0.8741 - val_f1_m: 0.8874
# Epoch 69/128
# 1269869/1269869 [==============================] - 31s 24us/sample - loss: 0.2923 - acc: 0.8868 - precision_m: 0.9070 - recall_m: 0.8676 - f1_m: 0.8863 - val_loss: 0.2917 - val_acc: 0.8812 - val_precision_m: 0.9126 - val_recall_m: 0.8660 - val_f1_m: 0.8886
# Epoch 70/128
# 1269869/1269869 [==============================] - 31s 24us/sample - loss: 0.2919 - acc: 0.8871 - precision_m: 0.9060 - recall_m: 0.8685 - f1_m: 0.8863 - val_loss: 0.2910 - val_acc: 0.8924 - val_precision_m: 0.9037 - val_recall_m: 0.8800 - val_f1_m: 0.8917
# Epoch 71/128
# 1269869/1269869 [==============================] - 31s 24us/sample - loss: 0.2920 - acc: 0.8871 - precision_m: 0.9072 - recall_m: 0.8675 - f1_m: 0.8863 - val_loss: 0.2932 - val_acc: 0.9023 - val_precision_m: 0.9057 - val_recall_m: 0.8895 - val_f1_m: 0.8975
# Epoch 72/128
# 1269869/1269869 [==============================] - 31s 25us/sample - loss: 0.2916 - acc: 0.8872 - precision_m: 0.9061 - recall_m: 0.8685 - f1_m: 0.8863 - val_loss: 0.2896 - val_acc: 0.8884 - val_precision_m: 0.8910 - val_recall_m: 0.8841 - val_f1_m: 0.8875
# Epoch 73/128
# 1269869/1269869 [==============================] - 31s 24us/sample - loss: 0.2914 - acc: 0.8872 - precision_m: 0.9068 - recall_m: 0.8683 - f1_m: 0.8866 - val_loss: 0.2923 - val_acc: 0.8836 - val_precision_m: 0.8906 - val_recall_m: 0.8753 - val_f1_m: 0.8829
# Epoch 74/128
# 1269869/1269869 [==============================] - 31s 24us/sample - loss: 0.2914 - acc: 0.8873 - precision_m: 0.9069 - recall_m: 0.8683 - f1_m: 0.8866 - val_loss: 0.2990 - val_acc: 0.8978 - val_precision_m: 0.9034 - val_recall_m: 0.8942 - val_f1_m: 0.8988
# Epoch 75/128
# 1269869/1269869 [==============================] - 31s 24us/sample - loss: 0.2911 - acc: 0.8875 - precision_m: 0.9073 - recall_m: 0.8682 - f1_m: 0.8867 - val_loss: 0.2890 - val_acc: 0.8849 - val_precision_m: 0.8906 - val_recall_m: 0.8714 - val_f1_m: 0.8809
# Epoch 76/128
# 1269869/1269869 [==============================] - 31s 24us/sample - loss: 0.2909 - acc: 0.8876 - precision_m: 0.9079 - recall_m: 0.8681 - f1_m: 0.8870 - val_loss: 0.2904 - val_acc: 0.8925 - val_precision_m: 0.9015 - val_recall_m: 0.8818 - val_f1_m: 0.8915
# Epoch 77/128
# 1269869/1269869 [==============================] - 31s 24us/sample - loss: 0.2905 - acc: 0.8876 - precision_m: 0.9072 - recall_m: 0.8688 - f1_m: 0.8870 - val_loss: 0.2894 - val_acc: 0.8884 - val_precision_m: 0.8978 - val_recall_m: 0.8798 - val_f1_m: 0.8887
# Epoch 78/128
# 1269869/1269869 [==============================] - 31s 24us/sample - loss: 0.2902 - acc: 0.8878 - precision_m: 0.9078 - recall_m: 0.8684 - f1_m: 0.8871 - val_loss: 0.2895 - val_acc: 0.8970 - val_precision_m: 0.9004 - val_recall_m: 0.8894 - val_f1_m: 0.8949
# Epoch 79/128
# 1269869/1269869 [==============================] - 31s 24us/sample - loss: 0.2903 - acc: 0.8877 - precision_m: 0.9082 - recall_m: 0.8682 - f1_m: 0.8872 - val_loss: 0.2882 - val_acc: 0.8843 - val_precision_m: 0.8893 - val_recall_m: 0.8778 - val_f1_m: 0.8835
# Epoch 80/128
# 1269869/1269869 [==============================] - 31s 24us/sample - loss: 0.2900 - acc: 0.8879 - precision_m: 0.9087 - recall_m: 0.8685 - f1_m: 0.8876 - val_loss: 0.2912 - val_acc: 0.8810 - val_precision_m: 0.9433 - val_recall_m: 0.8187 - val_f1_m: 0.8765
# Epoch 81/128
# 1269869/1269869 [==============================] - 31s 24us/sample - loss: 0.2895 - acc: 0.8878 - precision_m: 0.9081 - recall_m: 0.8687 - f1_m: 0.8874 - val_loss: 0.2879 - val_acc: 0.8925 - val_precision_m: 0.9033 - val_recall_m: 0.8798 - val_f1_m: 0.8914
# Epoch 82/128
# 1269869/1269869 [==============================] - 31s 25us/sample - loss: 0.2893 - acc: 0.8881 - precision_m: 0.9086 - recall_m: 0.8686 - f1_m: 0.8876 - val_loss: 0.2892 - val_acc: 0.8869 - val_precision_m: 0.8908 - val_recall_m: 0.8820 - val_f1_m: 0.8864
# Epoch 83/128
# 1269869/1269869 [==============================] - 31s 24us/sample - loss: 0.2891 - acc: 0.8884 - precision_m: 0.9096 - recall_m: 0.8682 - f1_m: 0.8878 - val_loss: 0.2875 - val_acc: 0.8814 - val_precision_m: 0.9405 - val_recall_m: 0.8479 - val_f1_m: 0.8917
# Epoch 84/128
# 1269869/1269869 [==============================] - 31s 24us/sample - loss: 0.2888 - acc: 0.8887 - precision_m: 0.9099 - recall_m: 0.8685 - f1_m: 0.8882 - val_loss: 0.2955 - val_acc: 0.8796 - val_precision_m: 0.9452 - val_recall_m: 0.8159 - val_f1_m: 0.8757
# Epoch 85/128
# 1269869/1269869 [==============================] - 31s 24us/sample - loss: 0.2885 - acc: 0.8885 - precision_m: 0.9094 - recall_m: 0.8689 - f1_m: 0.8881 - val_loss: 0.2881 - val_acc: 0.8819 - val_precision_m: 0.9439 - val_recall_m: 0.8204 - val_f1_m: 0.8777
# Epoch 86/128
# 1269869/1269869 [==============================] - 31s 25us/sample - loss: 0.2884 - acc: 0.8887 - precision_m: 0.9095 - recall_m: 0.8693 - f1_m: 0.8884 - val_loss: 0.2923 - val_acc: 0.9009 - val_precision_m: 0.9035 - val_recall_m: 0.8982 - val_f1_m: 0.9008
# Epoch 87/128
# 1269869/1269869 [==============================] - 31s 24us/sample - loss: 0.2880 - acc: 0.8890 - precision_m: 0.9101 - recall_m: 0.8692 - f1_m: 0.8887 - val_loss: 0.2885 - val_acc: 0.8972 - val_precision_m: 0.9014 - val_recall_m: 0.8884 - val_f1_m: 0.8948
# Epoch 88/128
# 1269869/1269869 [==============================] - 31s 24us/sample - loss: 0.2875 - acc: 0.8890 - precision_m: 0.9101 - recall_m: 0.8695 - f1_m: 0.8888 - val_loss: 0.2874 - val_acc: 0.8847 - val_precision_m: 0.9435 - val_recall_m: 0.8520 - val_f1_m: 0.8953
# Epoch 89/128
# 1269869/1269869 [==============================] - 31s 24us/sample - loss: 0.2872 - acc: 0.8893 - precision_m: 0.9105 - recall_m: 0.8695 - f1_m: 0.8890 - val_loss: 0.2871 - val_acc: 0.8810 - val_precision_m: 0.9433 - val_recall_m: 0.8187 - val_f1_m: 0.8765
# Epoch 90/128
# 1269869/1269869 [==============================] - 31s 24us/sample - loss: 0.2871 - acc: 0.8894 - precision_m: 0.9110 - recall_m: 0.8693 - f1_m: 0.8891 - val_loss: 0.2858 - val_acc: 0.8848 - val_precision_m: 0.9135 - val_recall_m: 0.8768 - val_f1_m: 0.8948
# Epoch 91/128
# 1269869/1269869 [==============================] - 31s 24us/sample - loss: 0.2864 - acc: 0.8899 - precision_m: 0.9115 - recall_m: 0.8694 - f1_m: 0.8895 - val_loss: 0.2846 - val_acc: 0.8959 - val_precision_m: 0.9008 - val_recall_m: 0.8798 - val_f1_m: 0.8901
# Epoch 92/128
# 1269869/1269869 [==============================] - 31s 25us/sample - loss: 0.2862 - acc: 0.8901 - precision_m: 0.9117 - recall_m: 0.8698 - f1_m: 0.8897 - val_loss: 0.2860 - val_acc: 0.8960 - val_precision_m: 0.9012 - val_recall_m: 0.8914 - val_f1_m: 0.8963
# Epoch 93/128
# 1269869/1269869 [==============================] - 31s 24us/sample - loss: 0.2859 - acc: 0.8904 - precision_m: 0.9121 - recall_m: 0.8698 - f1_m: 0.8900 - val_loss: 0.2833 - val_acc: 0.8949 - val_precision_m: 0.9016 - val_recall_m: 0.8799 - val_f1_m: 0.8906
# Epoch 94/128
# 1269869/1269869 [==============================] - 31s 24us/sample - loss: 0.2855 - acc: 0.8905 - precision_m: 0.9119 - recall_m: 0.8704 - f1_m: 0.8902 - val_loss: 0.2864 - val_acc: 0.8846 - val_precision_m: 0.9027 - val_recall_m: 0.8787 - val_f1_m: 0.8905
# Epoch 95/128
# 1269869/1269869 [==============================] - 31s 24us/sample - loss: 0.2852 - acc: 0.8911 - precision_m: 0.9133 - recall_m: 0.8699 - f1_m: 0.8906 - val_loss: 0.2838 - val_acc: 0.8942 - val_precision_m: 0.9048 - val_recall_m: 0.8777 - val_f1_m: 0.8910
# Epoch 96/128
# 1269869/1269869 [==============================] - 31s 25us/sample - loss: 0.2847 - acc: 0.8911 - precision_m: 0.9134 - recall_m: 0.8710 - f1_m: 0.8912 - val_loss: 0.2871 - val_acc: 0.8996 - val_precision_m: 0.9360 - val_recall_m: 0.8223 - val_f1_m: 0.8753
# Epoch 97/128
# 1269869/1269869 [==============================] - 30s 24us/sample - loss: 0.2841 - acc: 0.8919 - precision_m: 0.9137 - recall_m: 0.8708 - f1_m: 0.8913 - val_loss: 0.2870 - val_acc: 0.9000 - val_precision_m: 0.9368 - val_recall_m: 0.8208 - val_f1_m: 0.8749
# Epoch 98/128
# 1269869/1269869 [==============================] - 31s 24us/sample - loss: 0.2839 - acc: 0.8917 - precision_m: 0.9142 - recall_m: 0.8714 - f1_m: 0.8918 - val_loss: 0.2820 - val_acc: 0.8933 - val_precision_m: 0.9048 - val_recall_m: 0.8878 - val_f1_m: 0.8962
# Epoch 99/128
# 1269869/1269869 [==============================] - 31s 24us/sample - loss: 0.2832 - acc: 0.8926 - precision_m: 0.9148 - recall_m: 0.8713 - f1_m: 0.8920 - val_loss: 0.2833 - val_acc: 0.9020 - val_precision_m: 0.9063 - val_recall_m: 0.8935 - val_f1_m: 0.8998
# Epoch 100/128
# 1269869/1269869 [==============================] - 31s 24us/sample - loss: 0.2829 - acc: 0.8930 - precision_m: 0.9155 - recall_m: 0.8713 - f1_m: 0.8924 - val_loss: 0.2886 - val_acc: 0.9020 - val_precision_m: 0.9042 - val_recall_m: 0.8949 - val_f1_m: 0.8995
# Epoch 101/128
# 1269869/1269869 [==============================] - 31s 24us/sample - loss: 0.2821 - acc: 0.8938 - precision_m: 0.9162 - recall_m: 0.8725 - f1_m: 0.8934 - val_loss: 0.2809 - val_acc: 0.8991 - val_precision_m: 0.9361 - val_recall_m: 0.8667 - val_f1_m: 0.9000
# Epoch 102/128
# 1269869/1269869 [==============================] - 31s 25us/sample - loss: 0.2818 - acc: 0.8942 - precision_m: 0.9166 - recall_m: 0.8725 - f1_m: 0.8936 - val_loss: 0.2823 - val_acc: 0.8940 - val_precision_m: 0.9026 - val_recall_m: 0.8852 - val_f1_m: 0.8938
# Epoch 103/128
# 1269869/1269869 [==============================] - 31s 24us/sample - loss: 0.2813 - acc: 0.8946 - precision_m: 0.9172 - recall_m: 0.8726 - f1_m: 0.8939 - val_loss: 0.2821 - val_acc: 0.8855 - val_precision_m: 0.9172 - val_recall_m: 0.8754 - val_f1_m: 0.8958
# Epoch 104/128
# 1269869/1269869 [==============================] - 31s 24us/sample - loss: 0.2805 - acc: 0.8950 - precision_m: 0.9172 - recall_m: 0.8736 - f1_m: 0.8945 - val_loss: 0.2797 - val_acc: 0.9006 - val_precision_m: 0.9075 - val_recall_m: 0.8910 - val_f1_m: 0.8992
# Epoch 105/128
# 1269869/1269869 [==============================] - 31s 24us/sample - loss: 0.2799 - acc: 0.8961 - precision_m: 0.9184 - recall_m: 0.8740 - f1_m: 0.8952 - val_loss: 0.2768 - val_acc: 0.8921 - val_precision_m: 0.9243 - val_recall_m: 0.8783 - val_f1_m: 0.9007
# Epoch 106/128
# 1269869/1269869 [==============================] - 31s 25us/sample - loss: 0.2790 - acc: 0.8964 - precision_m: 0.9188 - recall_m: 0.8745 - f1_m: 0.8958 - val_loss: 0.2760 - val_acc: 0.8893 - val_precision_m: 0.9141 - val_recall_m: 0.8815 - val_f1_m: 0.8975
# Epoch 107/128
# 1269869/1269869 [==============================] - 30s 24us/sample - loss: 0.2782 - acc: 0.8969 - precision_m: 0.9194 - recall_m: 0.8756 - f1_m: 0.8967 - val_loss: 0.2768 - val_acc: 0.9042 - val_precision_m: 0.9400 - val_recall_m: 0.8681 - val_f1_m: 0.9025
# Epoch 108/128
# 1269869/1269869 [==============================] - 31s 24us/sample - loss: 0.2772 - acc: 0.8982 - precision_m: 0.9209 - recall_m: 0.8762 - f1_m: 0.8977 - val_loss: 0.2744 - val_acc: 0.8959 - val_precision_m: 0.9198 - val_recall_m: 0.8797 - val_f1_m: 0.8993
# Epoch 109/128
# 1269869/1269869 [==============================] - 31s 24us/sample - loss: 0.2767 - acc: 0.8993 - precision_m: 0.9216 - recall_m: 0.8764 - f1_m: 0.8981 - val_loss: 0.2739 - val_acc: 0.8969 - val_precision_m: 0.9089 - val_recall_m: 0.8891 - val_f1_m: 0.8988
# Epoch 110/128
# 1269869/1269869 [==============================] - 30s 24us/sample - loss: 0.2755 - acc: 0.8995 - precision_m: 0.9220 - recall_m: 0.8777 - f1_m: 0.8991 - val_loss: 0.2782 - val_acc: 0.9010 - val_precision_m: 0.9061 - val_recall_m: 0.8965 - val_f1_m: 0.9013
# Epoch 111/128
# 1269869/1269869 [==============================] - 30s 24us/sample - loss: 0.2748 - acc: 0.9004 - precision_m: 0.9228 - recall_m: 0.8782 - f1_m: 0.8997 - val_loss: 0.2848 - val_acc: 0.8713 - val_precision_m: 0.9295 - val_recall_m: 0.8484 - val_f1_m: 0.8870
# Epoch 112/128
# 1269869/1269869 [==============================] - 31s 25us/sample - loss: 0.2744 - acc: 0.9012 - precision_m: 0.9235 - recall_m: 0.8787 - f1_m: 0.9002 - val_loss: 0.2708 - val_acc: 0.9065 - val_precision_m: 0.9219 - val_recall_m: 0.8856 - val_f1_m: 0.9033
# Epoch 113/128
# 1269869/1269869 [==============================] - 30s 24us/sample - loss: 0.2727 - acc: 0.9025 - precision_m: 0.9248 - recall_m: 0.8800 - f1_m: 0.9016 - val_loss: 0.2707 - val_acc: 0.9029 - val_precision_m: 0.9245 - val_recall_m: 0.8858 - val_f1_m: 0.9047
# Epoch 114/128
# 1269869/1269869 [==============================] - 31s 24us/sample - loss: 0.2720 - acc: 0.9035 - precision_m: 0.9257 - recall_m: 0.8810 - f1_m: 0.9025 - val_loss: 0.2706 - val_acc: 0.8996 - val_precision_m: 0.9300 - val_recall_m: 0.8889 - val_f1_m: 0.9089
# Epoch 115/128
# 1269869/1269869 [==============================] - 31s 24us/sample - loss: 0.2713 - acc: 0.9044 - precision_m: 0.9264 - recall_m: 0.8823 - f1_m: 0.9036 - val_loss: 0.2676 - val_acc: 0.9072 - val_precision_m: 0.9348 - val_recall_m: 0.8814 - val_f1_m: 0.9073
# Epoch 116/128
# 1269869/1269869 [==============================] - 31s 25us/sample - loss: 0.2700 - acc: 0.9053 - precision_m: 0.9271 - recall_m: 0.8836 - f1_m: 0.9046 - val_loss: 0.2699 - val_acc: 0.9109 - val_precision_m: 0.9286 - val_recall_m: 0.8969 - val_f1_m: 0.9124
# Epoch 117/128
# 1269869/1269869 [==============================] - 31s 24us/sample - loss: 0.2693 - acc: 0.9064 - precision_m: 0.9279 - recall_m: 0.8845 - f1_m: 0.9055 - val_loss: 0.2686 - val_acc: 0.9044 - val_precision_m: 0.9164 - val_recall_m: 0.8979 - val_f1_m: 0.9071
# Epoch 118/128
# 1269869/1269869 [==============================] - 31s 24us/sample - loss: 0.2679 - acc: 0.9077 - precision_m: 0.9290 - recall_m: 0.8859 - f1_m: 0.9067 - val_loss: 0.2775 - val_acc: 0.9011 - val_precision_m: 0.9053 - val_recall_m: 0.8993 - val_f1_m: 0.9022
# Epoch 119/128
# 1269869/1269869 [==============================] - 31s 24us/sample - loss: 0.2671 - acc: 0.9087 - precision_m: 0.9299 - recall_m: 0.8867 - f1_m: 0.9076 - val_loss: 0.2655 - val_acc: 0.9122 - val_precision_m: 0.9307 - val_recall_m: 0.9003 - val_f1_m: 0.9152
# Epoch 120/128
# 1269869/1269869 [==============================] - 31s 24us/sample - loss: 0.2663 - acc: 0.9095 - precision_m: 0.9304 - recall_m: 0.8883 - f1_m: 0.9087 - val_loss: 0.2774 - val_acc: 0.8978 - val_precision_m: 0.9042 - val_recall_m: 0.8930 - val_f1_m: 0.8986
# Epoch 121/128
# 1269869/1269869 [==============================] - 31s 24us/sample - loss: 0.2647 - acc: 0.9114 - precision_m: 0.9320 - recall_m: 0.8906 - f1_m: 0.9107 - val_loss: 0.2676 - val_acc: 0.9066 - val_precision_m: 0.9324 - val_recall_m: 0.8915 - val_f1_m: 0.9115
# Epoch 122/128
# 1269869/1269869 [==============================] - 31s 25us/sample - loss: 0.2644 - acc: 0.9113 - precision_m: 0.9320 - recall_m: 0.8903 - f1_m: 0.9105 - val_loss: 0.2601 - val_acc: 0.9175 - val_precision_m: 0.9398 - val_recall_m: 0.9020 - val_f1_m: 0.9205
# Epoch 123/128
# 1269869/1269869 [==============================] - 31s 24us/sample - loss: 0.2634 - acc: 0.9123 - precision_m: 0.9328 - recall_m: 0.8920 - f1_m: 0.9118 - val_loss: 0.2679 - val_acc: 0.9154 - val_precision_m: 0.9458 - val_recall_m: 0.8556 - val_f1_m: 0.8984
# Epoch 124/128
# 1269869/1269869 [==============================] - 31s 24us/sample - loss: 0.2621 - acc: 0.9142 - precision_m: 0.9343 - recall_m: 0.8943 - f1_m: 0.9137 - val_loss: 0.2607 - val_acc: 0.9150 - val_precision_m: 0.9491 - val_recall_m: 0.8909 - val_f1_m: 0.9190
# Epoch 125/128
# 1269869/1269869 [==============================] - 31s 24us/sample - loss: 0.2614 - acc: 0.9142 - precision_m: 0.9341 - recall_m: 0.8942 - f1_m: 0.9135 - val_loss: 0.2690 - val_acc: 0.9022 - val_precision_m: 0.9177 - val_recall_m: 0.8911 - val_f1_m: 0.9042
# Epoch 126/128
# 1269869/1269869 [==============================] - 31s 24us/sample - loss: 0.2604 - acc: 0.9151 - precision_m: 0.9351 - recall_m: 0.8958 - f1_m: 0.9149 - val_loss: 0.2802 - val_acc: 0.8871 - val_precision_m: 0.9200 - val_recall_m: 0.8645 - val_f1_m: 0.8913
# Epoch 127/128
# 1269869/1269869 [==============================] - 31s 24us/sample - loss: 0.2593 - acc: 0.9164 - precision_m: 0.9358 - recall_m: 0.8971 - f1_m: 0.9159 - val_loss: 0.2565 - val_acc: 0.9242 - val_precision_m: 0.9408 - val_recall_m: 0.9083 - val_f1_m: 0.9242
# Epoch 128/128
# 1269869/1269869 [==============================] - 31s 24us/sample - loss: 0.2581 - acc: 0.9177 - precision_m: 0.9370 - recall_m: 0.8993 - f1_m: 0.9176 - val_loss: 0.2666 - val_acc: 0.9102 - val_precision_m: 0.9345 - val_recall_m: 0.8906 - val_f1_m: 0.9120
# Time taken for the Network to train: 3947.58321959

# %% [markdown]
# ## **Plotting & Evaluating Metrics**

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score

#Evaluating
print("Evaluating...")
loss, accuracy, precision, recall, f1_score = model.evaluate(x_test, y_test, verbose=0, batch_size=1024)

print("Plotting the metrics...")
plt.rcParams["figure.figsize"] = [6,4]

# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()
print('Loss: %.2f%%' % (loss*100))

# Plot training & validation accuracy values
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()
print('Accuracy: %.2f%%' % (accuracy*100))

# Plot training & validation precision values
plt.plot(history.history['precision_m'])
plt.plot(history.history['val_precision_m'])
plt.title('Model Precision')
plt.ylabel('Precision')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()
print('Precision: %.2f%%' % (precision*100))

# Plot training & validation recall values
plt.plot(history.history['recall_m'])
plt.plot(history.history['val_recall_m'])
plt.title('Model Recall')
plt.ylabel('Recall')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()
print('Recall: %.2f%%' % (recall*100))

# Plot training & validation f1 score values
plt.plot(history.history['f1_m'])
plt.plot(history.history['val_f1_m'])
plt.title('Model F1 score')
plt.ylabel('F1 Score')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()
print('F1 Score: %.2f%%' % (f1_score*100))


# Final Score
print('\nFinal Score...')
y_p = model.predict(x_test)
y_pred = np.argmax(y_p,axis=1) #Return a 1D binary vector indicating the ID of the mac number in the row
y_eval = np.argmax(y_test,axis=1) #Return a 1D binary vector indicating the ID of the mac number in the row
score = accuracy_score(y_eval, y_pred)
print('Validation/Final Score: %.2f%%' % (score*100))
# Out:
# Evaluating...
# Plotting the metrics...
# Loss: 26.66%
# Accuracy: 91.02%
# Precision: 93.45%
# Recall: 89.06%
# F1 Score: 91.20%
#
# Final Score...
# Validation/Final Score: 91.02%

# %% [markdown]
# ## **Confusion Matrix**

# %%
# Measure accuracy
from sklearn.metrics import confusion_matrix
import itertools
import sys

# Confusion Matrix
def plot_confusion_matrix(cm, labels, classes, normalize=False, title='Confusion matrix', cmap=plt.cm.Greys):
    # This function prints and plots the confusion matrix. Normalization can be applied by setting `normalize=True`.
    plt.rcParams["figure.figsize"] = [10,10]
    plt.figure()
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')
    print(cm)

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    if labels is not None:
        tick_marks = np.arange(len(labels))
        plt.xticks(tick_marks, labels, rotation=60)
        plt.yticks(tick_marks, labels)
    else:
        tick_marks = np.arange(len(classes))
        plt.xticks(tick_marks, classes, rotation=45)
        plt.yticks(tick_marks, classes)

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        if normalize:
            plt.text(j, i, "{0:.4f}".format(cm[i, j]), horizontalalignment="center", color="white" if cm[i, j] > thresh else "black")
        else:
            plt.text(j, i, "{0:.0f}".format(cm[i, j]), horizontalalignment="center", color="white" if cm[i, j] > thresh else "black")
    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.show()

labels = ['Normal', 'Fuzzers', 'Analysis', 'Backdoor', 'DoS', 'Exploit', 'Generic', 'Reconnaissance', 'Shellcode', 'Worm']
cm = confusion_matrix(y_eval, y_pred)
plot_confusion_matrix(cm, labels, classes=list(range(9)), normalize=False, title='Confusion matrix')
plot_confusion_matrix(cm, labels, classes=list(range(9)), normalize=True, title='Confusion matrix normalized')
print("Each row adds 1 in total")
# Out:
# Confusion matrix, without normalization
# [[      0       1       2      53     110      11    1176       2       0
#         0]
#  [      0       7       7     112      37      11    1005       2       0
#         0]
#  [      0      10      74     644     373      88    6955      26       0
#         0]
#  [      0      12      65    1140    2456     129   18355      50       0
#         0]
#  [      0       1       5     139    3217     382    8347       3       0
#         0]
#  [      0       3       7     112     270   51388   56130       4       0
#         0]
#  [      0       0       6      37    6838    2195 1100045       1       4
#         0]
#  [      0       1       9     151    1668     704    4457       5       0
#         0]
#  [      0       0       0       0      45       0     693       0       0
#         0]
#  [      0       0       0       0      25       0      65       0       0
#         0]]
# Normalized confusion matrix
# [[0.00000000e+00 7.38007380e-04 1.47601476e-03 3.91143911e-02
#   8.11808118e-02 8.11808118e-03 8.67896679e-01 1.47601476e-03
#   0.00000000e+00 0.00000000e+00]
#  [0.00000000e+00 5.92718036e-03 5.92718036e-03 9.48348857e-02
#   3.13293819e-02 9.31414056e-03 8.50973751e-01 1.69348010e-03
#   0.00000000e+00 0.00000000e+00]
#  [0.00000000e+00 1.22399021e-03 9.05752754e-03 7.88249694e-02
#   4.56548348e-02 1.07711138e-02 8.51285190e-01 3.18237454e-03
#   0.00000000e+00 0.00000000e+00]
#  [0.00000000e+00 5.40370154e-04 2.92700500e-03 5.13351646e-02
#   1.10595758e-01 5.80897915e-03 8.26541181e-01 2.25154231e-03
#   0.00000000e+00 0.00000000e+00]
#  [0.00000000e+00 8.26856292e-05 4.13428146e-04 1.14933025e-02
#   2.65999669e-01 3.15859104e-02 6.90176947e-01 2.48056888e-04
#   0.00000000e+00 0.00000000e+00]
#  [0.00000000e+00 2.77999147e-05 6.48664677e-05 1.03786348e-03
#   2.50199233e-03 4.76194006e-01 5.20136405e-01 3.70665530e-05
#   0.00000000e+00 0.00000000e+00]
#  [0.00000000e+00 0.00000000e+00 5.40966491e-06 3.33596003e-05
#   6.16521477e-03 1.97903575e-03 9.91812472e-01 9.01610818e-07
#   3.60644327e-06 0.00000000e+00]
#  [0.00000000e+00 1.42959257e-04 1.28663331e-03 2.15868477e-02
#   2.38456040e-01 1.00643317e-01 6.37169407e-01 7.14796283e-04
#   0.00000000e+00 0.00000000e+00]
#  [0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#   6.09756098e-02 0.00000000e+00 9.39024390e-01 0.00000000e+00
#   0.00000000e+00 0.00000000e+00]
#  [0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#   2.77777778e-01 0.00000000e+00 7.22222222e-01 0.00000000e+00
#   0.00000000e+00 0.00000000e+00]]
# Each row adds 1 in total

# %% [markdown]
# ## **Error parameters**

# %%
print("Printing the parameters of each class...")
print("\n")
# TP
TP = np.diag(cm)

# FP
FP = []
for i in range(cm.shape[0]):
    FP.append(sum(cm[:,i]) - cm[i,i])

# FN    
FN = []
for i in range(cm.shape[0]):
    FN.append(sum(cm[i,:]) - cm[i,i])    

# TN
TN = []
for i in range(cm.shape[0]):
    temp = np.delete(cm, i, 0)   # delete ith row
    temp = np.delete(temp, i, 1)  # delete ith column
    TN.append(sum(sum(temp)))   

# Creating the lists
FPR = []
TNR = []
FNR = []
TPR = []
ACC = []
PRE = []
REC = []
F1 = []
for i in range(cm.shape[0]):
    fpri = FP[i]/(TN[i]+FP[i])*100
    tnri = TN[i]/(TN[i]+FP[i])*100
    fnri = FN[i]/(FN[i]+TP[i])*100
    tpri = TP[i]/(TP[i]+FN[i])*100
    acci = (TP[i]+TN[i])/(TP[i]+FN[i]+TN[i]+FP[i])*100
    prei = TP[i]/(TP[i]+FP[i])*100
    reci = TP[i]/(TP[i]+FN[i])*100
    f1i = 2*(prei*reci)/(prei+reci)

    FPR.append(round(fpri,2))
    TNR.append(round(tnri,2))
    FNR.append(round(fnri,2))
    TPR.append(round(tpri,2))
    ACC.append(round(acci,2))
    PRE.append(round(prei,2))
    REC.append(round(reci,2))
    F1.append(round(f1i,2))

# Making a dataframe for printing a table
TPs=np.asarray(TP)
FPs=np.asarray(FP)
FNs=np.asarray(FN)
TNs=np.asarray(TN)
FPRs=np.asarray(FPR)
TNRs=np.asarray(TNR)
FNRs=np.asarray(FNR)
TPRs=np.asarray(TPR)
ACCs=np.asarray(ACC)
PREs=np.asarray(PRE)
RECs=np.asarray(REC)
F1s=np.asarray(F1)

TPt= TPs.reshape(TPs.shape[0], 1)
FPt= FPs.reshape(FPs.shape[0], 1)
FNt= FNs.reshape(FNs.shape[0], 1)
TNt= TNs.reshape(TNs.shape[0], 1)
FPRt= FPRs.reshape(FPRs.shape[0], 1)
TNRt= TNRs.reshape(TNRs.shape[0], 1)
FNRt= FNRs.reshape(FNRs.shape[0], 1)
TPRt= TPRs.reshape(TPRs.shape[0], 1)
ACCt= ACCs.reshape(ACCs.shape[0], 1)
PREt= PREs.reshape(PREs.shape[0], 1)
RECt= RECs.reshape(RECs.shape[0], 1)
F1t= F1s.reshape(F1s.shape[0], 1)

param = np.concatenate((TPt, FPt, FNt, TNt, FPRt, TNRt, FNRt, TPRt, ACCt, PREt, RECt, F1t), axis=1)

dfParam= pd.DataFrame(param, columns = ['TP', 'FP', 'FN', 'TN', 'FPR/FAR(%)', 'TNR(%)', 'FNR(%)', 'TPR/DR(%)', 'Accuracy(%)', 'Precision(%)', 'Recall(%)', 'F1 Score(%)'], index=labels)

dfParam[0:len(labels)]
# Out:
# Printing the parameters of each class...
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:38: RuntimeWarning: invalid value encountered in long_scalars
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:40: RuntimeWarning: invalid value encountered in double_scalars
#                        TP       FP  ...  Recall(%)  F1 Score(%)
# Normal                0.0      0.0  ...       0.00          NaN
# Fuzzers               7.0     28.0  ...       0.59         1.15
# Analysis             74.0    101.0  ...       0.91         1.77
# Backdoor           1140.0   1248.0  ...       5.13         9.27
# DoS                3217.0  11822.0  ...      26.60        23.71
# Exploit           51388.0   3520.0  ...      47.62        63.12
# Generic         1100045.0  97183.0  ...      99.18        95.39
# Reconnaissance        5.0     88.0  ...       0.07         0.14
# Shellcode             0.0      4.0  ...       0.00          NaN
# Worm                  0.0      0.0  ...       0.00          NaN
#
# [10 rows x 12 columns]

# %% [markdown]
# ## **ROC**

# %%
# ROC
def plot_roc_curve(Y_test, Y_pred, classes, labels):
    from sklearn import metrics
    import matplotlib.pyplot as plt
    fpr = dict()
    tpr = dict()
    roc_auc = dict()
    for i in range(classes):
        fpr[i], tpr[i], _ = metrics.roc_curve(Y_test[:, i], Y_pred[:, i])
        roc_auc[i] = metrics.auc(fpr[i], tpr[i])   
    # Compute micro-average ROC curve and ROC area
    fpr["micro"], tpr["micro"], _ = metrics.roc_curve(Y_test.ravel(), Y_pred.ravel())
    roc_auc["micro"] = metrics.auc(fpr["micro"], tpr["micro"])   
    #plt.figure()
    lw = 2
    plt.rcParams["figure.figsize"] = [6,4]
    for i in range(classes):
      plt.plot(fpr[i], tpr[i], color='darkorange',
              lw=lw, label='ROC curve (area = %0.4f)' % roc_auc[i])
      plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')
      plt.xlim([0.0, 1.0])
      plt.ylim([0.0, 1.05])
      plt.xlabel('False Positive Rate')
      plt.ylabel('True Positive Rate')
      plt.title('Receiver operating characteristic (class '+ str(i+1) +', '+ labels[i] +')')
      plt.legend(loc="lower right")
      plt.show()

plot_roc_curve(y_test, y_p, len(labels), labels)
